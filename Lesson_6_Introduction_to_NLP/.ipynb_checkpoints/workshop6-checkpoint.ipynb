# %% [markdown]
# # Построение Word2Vec-модели на базе комментариев пользователей сайта
#
# В этом воркшопе мы с вами научимся подготавливать текст для работы и строить word2vec-модель. Для этого мы будем использовать уже готовые инструменты, имеющиеся в NLTK и Gensim. На примере этой задачи мы с вами научимся использовать новые инструменты для задач NLP и посмотрим на базовые свойства word2vec-моделей.
#
# Комментарии хранятся в бинарном файле, упакованном при помощи pickle.

# %%
import pickle

# %%
# в файле - список комментариев, давайте прочитаем его

with open('comments.list', 'rb') as file:
    comments = pickle.load(file)

# %%
len(comments)
# Out:
# 300000

# %% [markdown]
# На самом деле 300 тысяч комментариев - это весьма малый массив данных для обучения хорошей модели. Обычно, чтобы построить хороший ебмеддинг, нужно проанализировать десятки и сотни гигабайт текста. Но чтобы не заставлять вас качать гигабайты данных, для нашей учебной задачи давайте воспользуемся таким небольшим датасетом.

# %%
# посмотрим, как выглядят комменты

comments[:50]
# Out:
# ['Почему кривые, если площадей нема',
#  'Никто - это одно слово, а не два.',
#  'Примерно треть людей в нашем городе (областном центре) получают ниже 15тр... И я не работаю пом.маш. но вкурсе зарплат.',
#  'Так девяностые, блин, сплошная сказка. Там не катило в одном ключе.\xa0 Проснулся - страны нет, заснул - еще хуже. Чего один Горбачев стоил. Я его взахлеб слушал. И ни одной фразы, смысла, не понимал.',
#  'Где в видео сказано, что он ее выгуливал?',
#  'Я к вам обращаюсь, а не к Гуглу. Или у вас своего понимания нет?',
#  'Чувствуется свежий напор!',
#  'Кстати, у него на яйках белое пятнышко и это очень мило)',
#  'Всё у тебя продумано!)',
#  'В списке ЦСКА нет. Но болею за ЦСКА с 2003 года. )))',
#  'То есть это два разных документа надо подать или в одном все сделать? Какой алгоритм?Сначала ходатайство на восстановление сроков, дожидаемся решения суда и на отмену или как? Или сразу две бумаги?',
#  'Так весь кавказ живёт',
#  'В условиях эпидемии не может быть своей позиции. В условиях эпидемии может быть лишь исполнение приказов Роспотребнадзора. ',
#  'Это бабушки обычно наперебой учат неоперившуюся мать. Даже если это её десятый ребёнок. Всё равно, мыльце в жопу - самый верный путь',
#  'Это новейшая разработка, стилизованная под отсталые проводные технологии',
#  'Я конечно понимаю что не следует опускаться до уровня подобных отбросов, но пиздец как хочется отплатить этой обезьянке его же монетой.',
#  'Чернота-то какая, чернотааа!',
#  'Ну, может думали - что это не ваш ребёнок...',
#  'И что из этого ваш случай? Почему вам неприятно смотреть на половые органы? ',
#  'Подозреваю, что их никто не спрашивает. Официально издаваться на CD и прочем, вроде, вообще дорогое удовольствие. Насколько я помню, исполнители с этого получают приблизительно нихрена, живут на концертах. Так что покупка дисков или альбомов на сервисах кормит в основном сами сервисы и студии звукозаписи.',
#  'Вполне держит норм, не отвалилась ещё. Я тоже не всегда в городе, а фара нужна в любом случае, в слабом режиме как габарит. Ну и вечерами катать ессно.',
#  'так его и не было. ',
#  'А чё тут сидишь в лохматом, если тебе чуждо все американское. Письма пиши своим идея мышлиникам\xa0 почтой России. Капитализация\xa0 только одной Аppl, как 22 Газпрома. И это все началось с мохнатых 70 годов, а точнее с однокристального микропроцессора компании Intel.\xa0 А остальное это пожинание плодов данной разработки.\xa0 А это тебе для твоего умственного развития: подвеска танка Т-34 это модернизированная подвеска американца\xa0 Джона Кристи запатентованная им в 1931 году.\xa0 Позже патент на производство был продан СССР и в Стране Советов пошел в серию танк БТ-2 с данной подвеской.\xa0 "Кузькину мать\' ещё не забывай и оперативке от Майкрософт привет. ',
#  'Открыть брокерский счет в Сбербанке, и снимать без проблем в течении часа, хотя заявлено 2дня',
#  'Ну что ж, считайте, один единорог Вам в жизни встретился)))',
#  'А можно отметить где летят детки ебучие?',
#  'https://youtu.be/FhWtJ2OwZ4A',
#  'Ну так про неё автор и говорит.Что Маск разрабатывает полностью многоразовую ракету и испытывает её в Бока Чика, ракета в которой корабль выполняет роль второй ступени.',
#  'Предлагает людям лезть под дубинки и получать штрафы и сроки за неё, пока она сидит в 5 звездочном отеле',
#  'И в чем кривость рук? Под толчком явный слив для воды из душа. Так и задумано, явно.',
#  'Тоже понравилась строчка про истекшую гарантию. Вот ведь досада! Они стопудово специально так делают, чтобы монитор падал сразу как гарантия кончается. :)',
#  'Все херня. Мой имт никогда не превышал 21, при этом я даже близко не придерживаюсь этих правил. 1. Не завтракаю, ибо просыпаю2. Воду не пью, особенно перед едой3. Совершенно без понятия из чего готовят то, что я ем, особенно чипсы, колбаса и полуфабрикаты4. В ресторане я могу заказать невесть что с интересным названием, совершенно не беспокоюсь о том, сколько там масла, жира и калорий5. Я всегда ем уткнувшись в телефон, книгу\xa0 работу. Исключение - если я ем не одна, да и то не всегда.Да, я прекрасно понимаю, что я правила частично извратила. Но если б было все так просто, то ожирение бы не было такой проблемой',
#  'А как же гордость? Норвежцев обогнали там... Сарказм',
#  'Охренеть, то есть инкассаторы были пьяные, с оружием, это ж пздц',
#  'ну да.Тюрки, мусульмане= русские..Жесть что у людей в голове.',
#  'В 17 году армия была обозленная на власть, после позора в первой мировой войне и наплевательского отношения к ним. ',
#  'Когда был студентом постоянно ходили по религиозным праздникам питаться, кормили всех желающих. ',
#  'Я пил в bubble tea. Обычный чай с шариками сока.',
#  'И при знакомых, гостях',
#  'В смысле "вместо"? Хуже некуда, когда человек ничего не понимает в какой-то области, но при этом раздает советы.УЗО применяется только совместно с автоматом, потому что оно не защищает от перегрузки по току.Есть еще дифференциальные автоматы, вот они как раз объединяют в себе функции УЗО и АВ.',
#  'Еще деньги на билет давать! Да пошла она нахуй! Ее еще суку и подставить что бы жизнь медом не казалась! Таких тварей учить нужно, а то они и дальше так по миру кататься будут. Ну а ебальничек начистить тоже можно для профилактики! И пошли нахуй те кто говорит что баб бить нельзя! Если эта тварь поиграла твоими чувствами, растоптала твое самоуважение (слабохарактерные после такого могут и с собой покончить) то уж один разок щелкнуть ей как следует\xa0 не будет лишним! И даже для своей психики ты этим сделаешь лучше в некотором смысле не так обидно будет, дальше жить!',
#  'Там не демоны..это Фуга..',
#  'Храни вас господь братья русские ',
#  'Нууууу....не то, чтобы массово. Так-то в специализированных магазинах всегда можно было всяких\xa0 странных интересностей прикупить.',
#  'Похоже на камеру для пыток и слив для крови предусмотрен)',
#  'Мне взрослому уже задолбала везде эта повесточка, хотя раньше в гомосексуалистам относился никак, больше с юмором, то теперь своей активностью в культуре и демонстрацией что они не такие как все - кроме раздражения ничего не вызывают. ',
#  'своего товарища Мишу Л.Таких друзей, за хуй - в музей!',
#  '6 правило, без которого первые 5 будут иметь сомнительный эффект:Физическая активность на протяжении всего дня. Вы никогда не сможете набрать лишний вес, если будете сжигать больше, чем закидываете в топку.Сидишь в офисе - хотя бы приседай раз в час в 3 подхода по 10 раз. Будут косо смотреть - скажи врач строго рекомендовал.',
#  'Ты таблетки забыл принять?',
#  'Это же скриншоты из FarCry 3! ']

# %% [markdown]
# Как мы видим, текст требует некоторой предобработки. Как минимум, нам не нужны знаки препинания и заглавные буквы...
#
# Для дальнейшей предобработки воспользуемся инструментами, имеющимися в NLTK.

# %%
# установите NLTK, если его у вас нет

# !pip install nltk

# %%
# в NLTK уже имеются списки стоп-слов для разных языков
# давайте им воспользуемся
from nltk.corpus import stopwords

# токенизацию будем выполнять при помощи функции word_tokenize
from nltk.tokenize import word_tokenize

# будем осуществлять стеммизацию слов при помощи RussianStemmer
from nltk.stem.snowball import RussianStemmer

# %% [markdown]
# Если вы используете NLTK впервые, он может выкинуть исключение с просьбой докачать данные. В таком случае просто выполните команду, которую он предлагает.

# %% [markdown]
# Давайте посмотрим, что у нас находится в русских стоп-словах:

# %%
stopwords.words('russian')
# Out:
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %% [markdown]
# Для дальнейшего использования сохраним их в виде множества, чтобы можно было быстро обращаться к нему операцией `in`.

# %%
stop_words = set(stopwords.words('russian'))

# %% [markdown]
# Токенизатор разделяет текст на токены: слова, знаки пунктуации...
#
# Давайте посмотрим на пример его работы.

# %%
print(f"Оригинальный коммент: {comments[1]}")
print(f"После токенизации: {word_tokenize(comments[1])}")
# Out:
# Оригинальный коммент: Никто - это одно слово, а не два.
# После токенизации: ['Никто', '-', 'это', 'одно', 'слово', ',', 'а', 'не', 'два', '.']

# %% [markdown]
# Для стеммизации нужно сперва создать объект класса.
#
# Тоже посмотрим, как он работает.

# %%
stemmer = RussianStemmer()

print(f"комментировать: {stemmer.stem('комментировать')}")
print(f"собаки: {stemmer.stem('собаки')}")
print(f"красное: {stemmer.stem('красное')}")
# Out:
# комментировать: комментирова
# собаки: собак
# красное: красн

# %% [markdown]
# Перед тем, как работать с текстами, давайте их подготовим. Сперва приведём всё к нижнему регистру и токенизируем результат. Среди токенов оставим только те, что состоят из букв и не являются стоп-словами. Оставшиеся токены подвергнем стеммизации

# %%
def preprocess(comment):
    # сначала комментарий преобразуем к нижнему регистру
    # заглавные буквы нам ни к чему
    comment = comment.lower()

    # токенизируем текст, получив список токенов
    tokens = word_tokenize(comment)

    # в списке оставим только те токены, что являются словами (выкинув, например, знаки препинания)
    # также выкинем стоп-слова
    # всё, что осталось, подвергнем стеммизации
    tokens = [stemmer.stem(t) for t in tokens if t.isalpha() and t not in stop_words]

    return tokens

# %%
comments = [preprocess(comm) for comm in comments]

# %%
# как теперь выглядит наш датасет

comments[:10]
# Out:
# [['поч', 'крив', 'площад', 'нем'],
#  ['никт', 'эт', 'одн', 'слов'],
#  ['примерн',
#   'трет',
#   'люд',
#   'наш',
#   'город',
#   'областн',
#   'центр',
#   'получа',
#   'ниж',
#   'работа',
#   'вкурс',
#   'зарплат'],
#  ['девян',
#   'блин',
#   'сплошн',
#   'сказк',
#   'кат',
#   'одн',
#   'ключ',
#   'проснул',
#   'стран',
#   'заснул',
#   'хуж',
#   'горбач',
#   'сто',
#   'взахлеб',
#   'слуша',
#   'одн',
#   'фраз',
#   'смысл',
#   'понима'],
#  ['виде', 'сказа', 'выгулива'],
#  ['обраща', 'гугл', 'сво', 'пониман'],
#  ['чувств', 'свеж', 'напор'],
#  ['кстат', 'яйк', 'бел', 'пятнышк', 'эт', 'очен', 'мил'],
#  ['все', 'продума'],
#  ['списк', 'цска', 'бол', 'цска', 'год']]

# %% [markdown]
# Строить word2vec-модель мы будем при помощи пакета Gensim, в котором имеется множество инструментов для NLP.
#
# Установите его, если он у вас ещё не установлен.

# %%
# установите gensim, если он у вас ещё не установлен

# !pip install gensim

# %%
import gensim

# %% [markdown]
# Для построения word2vec-модели в gensim достаточно использовать уже имеющийся класс. В аргументах необходимо указать желаемые параметры модели: от размерности вектора до выбранного алгоритма построения.
#
# Обучение начнётся сразу после создания модели.

# %%
model = gensim.models.Word2Vec(comments,  # на вход подаём список "предложений"
                               size=100,  # размерность эмбеддинга
                               window=7,  # размер окна в word2vec
                               min_count=10,  # минимальное количество раз, которое должно встретиться слово
                               sg=1,  # в качестве алгоритма выбираем skip-gram, т.к. датасет небольшой
                               iter=30,  # количество эпох обучения
                               workers=4)  # количество потоков (укажите, исходя из количества ядер вашего процессора)

# %%
# сохраним для потомков

model.save('comments_model.w2v')

# %% [markdown]
# Теперь мы можем получать вектор для любого слова, имеющиегося в словаре (в данном случае - которое минимум 10 раз встретилось в нашем датасете).

# %%
# весь словарь хранится в объекте vocab

model.wv.vocab
# Out:
# {'поч': <gensim.models.keyedvectors.Vocab at 0x2a33b4ee490>,
#  'крив': <gensim.models.keyedvectors.Vocab at 0x2a33b4e8430>,
#  'площад': <gensim.models.keyedvectors.Vocab at 0x2a33b4e8130>,
#  'нем': <gensim.models.keyedvectors.Vocab at 0x2a33b4e8190>,
#  'никт': <gensim.models.keyedvectors.Vocab at 0x2a33ca9ad30>,
#  'эт': <gensim.models.keyedvectors.Vocab at 0x2a33ca9ad90>,
#  'одн': <gensim.models.keyedvectors.Vocab at 0x2a33ca9adc0>,
#  'слов': <gensim.models.keyedvectors.Vocab at 0x2a33ca9ae20>,
#  'примерн': <gensim.models.keyedvectors.Vocab at 0x2a33ca9ae80>,
#  'трет': <gensim.models.keyedvectors.Vocab at 0x2a33ca9a8b0>,
#  'люд': <gensim.models.keyedvectors.Vocab at 0x2a33ca9af10>,
#  'наш': <gensim.models.keyedvectors.Vocab at 0x2a33ca9af70>,
#  'город': <gensim.models.keyedvectors.Vocab at 0x2a33ca9afd0>,
#  'областн': <gensim.models.keyedvectors.Vocab at 0x2a33ca9a4c0>,
#  'центр': <gensim.models.keyedvectors.Vocab at 0x2a351dbb340>,
#  'получа': <gensim.models.keyedvectors.Vocab at 0x2a351dbb2e0>,
#  'ниж': <gensim.models.keyedvectors.Vocab at 0x2a351dbbb50>,
#  'работа': <gensim.models.keyedvectors.Vocab at 0x2a351dbb640>,
#  'вкурс': <gensim.models.keyedvectors.Vocab at 0x2a351dbb550>,
#  'зарплат': <gensim.models.keyedvectors.Vocab at 0x2a351dbb4f0>,
#  'девян': <gensim.models.keyedvectors.Vocab at 0x2a351dbb1c0>,
#  'блин': <gensim.models.keyedvectors.Vocab at 0x2a351dbb280>,
#  'сплошн': <gensim.models.keyedvectors.Vocab at 0x2a33cab9070>,
#  'сказк': <gensim.models.keyedvectors.Vocab at 0x2a33cab90d0>,
#  'кат': <gensim.models.keyedvectors.Vocab at 0x2a33cab9130>,
#  'ключ': <gensim.models.keyedvectors.Vocab at 0x2a33cab9190>,
#  'проснул': <gensim.models.keyedvectors.Vocab at 0x2a33cab91f0>,
#  'стран': <gensim.models.keyedvectors.Vocab at 0x2a33cab9250>,
#  'заснул': <gensim.models.keyedvectors.Vocab at 0x2a33cab92b0>,
#  'хуж': <gensim.models.keyedvectors.Vocab at 0x2a33cab9310>,
#  'горбач': <gensim.models.keyedvectors.Vocab at 0x2a33cab9370>,
#  'сто': <gensim.models.keyedvectors.Vocab at 0x2a33cab93d0>,
#  'слуша': <gensim.models.keyedvectors.Vocab at 0x2a33cab9430>,
#  'фраз': <gensim.models.keyedvectors.Vocab at 0x2a33cab9490>,
#  'смысл': <gensim.models.keyedvectors.Vocab at 0x2a33cab94f0>,
#  'понима': <gensim.models.keyedvectors.Vocab at 0x2a33cab9550>,
#  'виде': <gensim.models.keyedvectors.Vocab at 0x2a33cab95b0>,
#  'сказа': <gensim.models.keyedvectors.Vocab at 0x2a33cab9610>,
#  'выгулива': <gensim.models.keyedvectors.Vocab at 0x2a33cab9670>,
#  'обраща': <gensim.models.keyedvectors.Vocab at 0x2a33cab96d0>,
#  'гугл': <gensim.models.keyedvectors.Vocab at 0x2a33cab9730>,
#  'сво': <gensim.models.keyedvectors.Vocab at 0x2a33cab9790>,
#  'пониман': <gensim.models.keyedvectors.Vocab at 0x2a33cab97f0>,
#  'чувств': <gensim.models.keyedvectors.Vocab at 0x2a33cab9850>,
#  'свеж': <gensim.models.keyedvectors.Vocab at 0x2a33cab98b0>,
#  'напор': <gensim.models.keyedvectors.Vocab at 0x2a33cab9910>,
#  'кстат': <gensim.models.keyedvectors.Vocab at 0x2a33cab9970>,
#  'яйк': <gensim.models.keyedvectors.Vocab at 0x2a33cab99d0>,
#  'бел': <gensim.models.keyedvectors.Vocab at 0x2a33cab9a30>,
#  'пятнышк': <gensim.models.keyedvectors.Vocab at 0x2a33cab9a90>,
#  'очен': <gensim.models.keyedvectors.Vocab at 0x2a33cab9af0>,
#  'мил': <gensim.models.keyedvectors.Vocab at 0x2a33cab9b50>,
#  'все': <gensim.models.keyedvectors.Vocab at 0x2a33cab9bb0>,
#  'продума': <gensim.models.keyedvectors.Vocab at 0x2a33cab9c10>,
#  'списк': <gensim.models.keyedvectors.Vocab at 0x2a33cab9c70>,
#  'цска': <gensim.models.keyedvectors.Vocab at 0x2a33cab9cd0>,
#  'бол': <gensim.models.keyedvectors.Vocab at 0x2a33cab9d00>,
#  'год': <gensim.models.keyedvectors.Vocab at 0x2a33cab9d60>,
#  'разн': <gensim.models.keyedvectors.Vocab at 0x2a33cab9dc0>,
#  'документ': <gensim.models.keyedvectors.Vocab at 0x2a33cab9e20>,
#  'пода': <gensim.models.keyedvectors.Vocab at 0x2a33cab9e80>,
#  'сдела': <gensim.models.keyedvectors.Vocab at 0x2a33cab9ee0>,
#  'алгоритм': <gensim.models.keyedvectors.Vocab at 0x2a33cab9f40>,
#  'снача': <gensim.models.keyedvectors.Vocab at 0x2a33cab9fa0>,
#  'ходатайств': <gensim.models.keyedvectors.Vocab at 0x2a33caba040>,
#  'восстановлен': <gensim.models.keyedvectors.Vocab at 0x2a33caba0a0>,
#  'срок': <gensim.models.keyedvectors.Vocab at 0x2a33caba100>,
#  'дожида': <gensim.models.keyedvectors.Vocab at 0x2a33caba160>,
#  'решен': <gensim.models.keyedvectors.Vocab at 0x2a33caba1c0>,
#  'суд': <gensim.models.keyedvectors.Vocab at 0x2a33caba220>,
#  'отмен': <gensim.models.keyedvectors.Vocab at 0x2a33caba280>,
#  'сраз': <gensim.models.keyedvectors.Vocab at 0x2a33caba2e0>,
#  'две': <gensim.models.keyedvectors.Vocab at 0x2a33caba340>,
#  'бумаг': <gensim.models.keyedvectors.Vocab at 0x2a33caba3a0>,
#  'ве': <gensim.models.keyedvectors.Vocab at 0x2a33caba400>,
#  'кавказ': <gensim.models.keyedvectors.Vocab at 0x2a33caba460>,
#  'живет': <gensim.models.keyedvectors.Vocab at 0x2a33caba4c0>,
#  'услов': <gensim.models.keyedvectors.Vocab at 0x2a33caba520>,
#  'эпидем': <gensim.models.keyedvectors.Vocab at 0x2a33caba580>,
#  'позиц': <gensim.models.keyedvectors.Vocab at 0x2a33caba5e0>,
#  'лиш': <gensim.models.keyedvectors.Vocab at 0x2a33caba640>,
#  'исполнен': <gensim.models.keyedvectors.Vocab at 0x2a33caba6a0>,
#  'приказ': <gensim.models.keyedvectors.Vocab at 0x2a33caba700>,
#  'роспотребнадзор': <gensim.models.keyedvectors.Vocab at 0x2a33caba760>,
#  'бабушк': <gensim.models.keyedvectors.Vocab at 0x2a33caba7c0>,
#  'обычн': <gensim.models.keyedvectors.Vocab at 0x2a33caba820>,
#  'учат': <gensim.models.keyedvectors.Vocab at 0x2a33caba880>,
#  'мат': <gensim.models.keyedvectors.Vocab at 0x2a33caba8e0>,
#  'е': <gensim.models.keyedvectors.Vocab at 0x2a33caba940>,
#  'десят': <gensim.models.keyedvectors.Vocab at 0x2a33caba9a0>,
#  'ребенок': <gensim.models.keyedvectors.Vocab at 0x2a33cabaa00>,
#  'равн': <gensim.models.keyedvectors.Vocab at 0x2a33cabaa60>,
#  'жоп': <gensim.models.keyedvectors.Vocab at 0x2a33cabaac0>,
#  'сам': <gensim.models.keyedvectors.Vocab at 0x2a33cabab20>,
#  'верн': <gensim.models.keyedvectors.Vocab at 0x2a33cabab80>,
#  'пут': <gensim.models.keyedvectors.Vocab at 0x2a33cababe0>,
#  'нов': <gensim.models.keyedvectors.Vocab at 0x2a33cabac40>,
#  'разработк': <gensim.models.keyedvectors.Vocab at 0x2a33cabaca0>,
#  'отстал': <gensim.models.keyedvectors.Vocab at 0x2a33cabad00>,
#  'проводн': <gensim.models.keyedvectors.Vocab at 0x2a33cabad60>,
#  'технолог': <gensim.models.keyedvectors.Vocab at 0x2a33cabadc0>,
#  'след': <gensim.models.keyedvectors.Vocab at 0x2a33cabae20>,
#  'опуска': <gensim.models.keyedvectors.Vocab at 0x2a33cabae80>,
#  'уровн': <gensim.models.keyedvectors.Vocab at 0x2a33cabaee0>,
#  'подобн': <gensim.models.keyedvectors.Vocab at 0x2a33cabaf40>,
#  'отброс': <gensim.models.keyedvectors.Vocab at 0x2a33cabafa0>,
#  'пиздец': <gensim.models.keyedvectors.Vocab at 0x2a33cabc040>,
#  'хочет': <gensim.models.keyedvectors.Vocab at 0x2a33cabc0a0>,
#  'обезьянк': <gensim.models.keyedvectors.Vocab at 0x2a33cabc100>,
#  'монет': <gensim.models.keyedvectors.Vocab at 0x2a33cabc160>,
#  'дума': <gensim.models.keyedvectors.Vocab at 0x2a33cabc1c0>,
#  'ваш': <gensim.models.keyedvectors.Vocab at 0x2a33cabc220>,
#  'случа': <gensim.models.keyedvectors.Vocab at 0x2a33cabc280>,
#  'неприятн': <gensim.models.keyedvectors.Vocab at 0x2a33cabc2e0>,
#  'смотрет': <gensim.models.keyedvectors.Vocab at 0x2a33cabc340>,
#  'полов': <gensim.models.keyedvectors.Vocab at 0x2a33cabc3a0>,
#  'орга': <gensim.models.keyedvectors.Vocab at 0x2a33cabc400>,
#  'подозрева': <gensim.models.keyedvectors.Vocab at 0x2a33cabc460>,
#  'спрашива': <gensim.models.keyedvectors.Vocab at 0x2a33cabc4c0>,
#  'официальн': <gensim.models.keyedvectors.Vocab at 0x2a33cabc520>,
#  'издава': <gensim.models.keyedvectors.Vocab at 0x2a33cabc580>,
#  'cd': <gensim.models.keyedvectors.Vocab at 0x2a33cabc5e0>,
#  'проч': <gensim.models.keyedvectors.Vocab at 0x2a33cabc640>,
#  'врод': <gensim.models.keyedvectors.Vocab at 0x2a33cabc6a0>,
#  'вообщ': <gensim.models.keyedvectors.Vocab at 0x2a33cabc700>,
#  'дорог': <gensim.models.keyedvectors.Vocab at 0x2a33cabc760>,
#  'удовольств': <gensim.models.keyedvectors.Vocab at 0x2a33cabc7c0>,
#  'наскольк': <gensim.models.keyedvectors.Vocab at 0x2a33cabc820>,
#  'помн': <gensim.models.keyedvectors.Vocab at 0x2a33cabc880>,
#  'исполнител': <gensim.models.keyedvectors.Vocab at 0x2a33cabc8e0>,
#  'приблизительн': <gensim.models.keyedvectors.Vocab at 0x2a33cabc940>,
#  'нихр': <gensim.models.keyedvectors.Vocab at 0x2a33cabc9a0>,
#  'живут': <gensim.models.keyedvectors.Vocab at 0x2a33cabca00>,
#  'концерт': <gensim.models.keyedvectors.Vocab at 0x2a33cabca60>,
#  'покупк': <gensim.models.keyedvectors.Vocab at 0x2a33cabcac0>,
#  'диск': <gensim.models.keyedvectors.Vocab at 0x2a33cabcb20>,
#  'альбом': <gensim.models.keyedvectors.Vocab at 0x2a33cabcb80>,
#  'сервис': <gensim.models.keyedvectors.Vocab at 0x2a33cabcbe0>,
#  'корм': <gensim.models.keyedvectors.Vocab at 0x2a33cabcc40>,
#  'основн': <gensim.models.keyedvectors.Vocab at 0x2a33cabcca0>,
#  'студ': <gensim.models.keyedvectors.Vocab at 0x2a33cabcd00>,
#  'вполн': <gensim.models.keyedvectors.Vocab at 0x2a33cabcd60>,
#  'держ': <gensim.models.keyedvectors.Vocab at 0x2a33cabcdc0>,
#  'норм': <gensim.models.keyedvectors.Vocab at 0x2a33cabce20>,
#  'отвал': <gensim.models.keyedvectors.Vocab at 0x2a33cabce80>,
#  'ещ': <gensim.models.keyedvectors.Vocab at 0x2a33cabcee0>,
#  'фар': <gensim.models.keyedvectors.Vocab at 0x2a33cabcf40>,
#  'нужн': <gensim.models.keyedvectors.Vocab at 0x2a33cabcfa0>,
#  'люб': <gensim.models.keyedvectors.Vocab at 0x2a33cabd040>,
#  'слаб': <gensim.models.keyedvectors.Vocab at 0x2a33cabd0a0>,
#  'режим': <gensim.models.keyedvectors.Vocab at 0x2a33cabd100>,
#  'вечер': <gensim.models.keyedvectors.Vocab at 0x2a33cabd160>,
#  'ката': <gensim.models.keyedvectors.Vocab at 0x2a33cabd1c0>,
#  'ессн': <gensim.models.keyedvectors.Vocab at 0x2a33cabd220>,
#  'че': <gensim.models.keyedvectors.Vocab at 0x2a33cabd280>,
#  'сид': <gensim.models.keyedvectors.Vocab at 0x2a33cabd2e0>,
#  'лохмат': <gensim.models.keyedvectors.Vocab at 0x2a33cabd340>,
#  'теб': <gensim.models.keyedvectors.Vocab at 0x2a33cabd3a0>,
#  'чужд': <gensim.models.keyedvectors.Vocab at 0x2a33cabd400>,
#  'американск': <gensim.models.keyedvectors.Vocab at 0x2a33cabd460>,
#  'письм': <gensim.models.keyedvectors.Vocab at 0x2a33cabd4c0>,
#  'пиш': <gensim.models.keyedvectors.Vocab at 0x2a33cabd520>,
#  'иде': <gensim.models.keyedvectors.Vocab at 0x2a33cabd580>,
#  'почт': <gensim.models.keyedvectors.Vocab at 0x2a33cabd5e0>,
#  'росс': <gensim.models.keyedvectors.Vocab at 0x2a33cabd640>,
#  'газпром': <gensim.models.keyedvectors.Vocab at 0x2a33cabd6a0>,
#  'нача': <gensim.models.keyedvectors.Vocab at 0x2a33cabd700>,
#  'мохнат': <gensim.models.keyedvectors.Vocab at 0x2a33cabd760>,
#  'точн': <gensim.models.keyedvectors.Vocab at 0x2a33cabd7c0>,
#  'компан': <gensim.models.keyedvectors.Vocab at 0x2a33cabd820>,
#  'intel': <gensim.models.keyedvectors.Vocab at 0x2a33cabd880>,
#  'остальн': <gensim.models.keyedvectors.Vocab at 0x2a33cabd8e0>,
#  'плод': <gensim.models.keyedvectors.Vocab at 0x2a33cabd940>,
#  'дан': <gensim.models.keyedvectors.Vocab at 0x2a33cabd9a0>,
#  'тво': <gensim.models.keyedvectors.Vocab at 0x2a33cabda00>,
#  'умствен': <gensim.models.keyedvectors.Vocab at 0x2a33cabda60>,
#  'развит': <gensim.models.keyedvectors.Vocab at 0x2a33cabdac0>,
#  'подвеск': <gensim.models.keyedvectors.Vocab at 0x2a33cabdb20>,
#  'танк': <gensim.models.keyedvectors.Vocab at 0x2a33cabdb80>,
#  'модернизирова': <gensim.models.keyedvectors.Vocab at 0x2a33cabdbe0>,
#  'американц': <gensim.models.keyedvectors.Vocab at 0x2a33cabdc40>,
#  'джон': <gensim.models.keyedvectors.Vocab at 0x2a33cabdca0>,
#  'крист': <gensim.models.keyedvectors.Vocab at 0x2a33cabdd00>,
#  'запатентова': <gensim.models.keyedvectors.Vocab at 0x2a33cabdd60>,
#  'позж': <gensim.models.keyedvectors.Vocab at 0x2a33cabddc0>,
#  'патент': <gensim.models.keyedvectors.Vocab at 0x2a33cabde20>,
#  'производств': <gensim.models.keyedvectors.Vocab at 0x2a33cabde80>,
#  'прода': <gensim.models.keyedvectors.Vocab at 0x2a33cabdee0>,
#  'ссср': <gensim.models.keyedvectors.Vocab at 0x2a33cabdf40>,
#  'совет': <gensim.models.keyedvectors.Vocab at 0x2a33cabdfa0>,
#  'пошел': <gensim.models.keyedvectors.Vocab at 0x2a33cabf040>,
#  'сер': <gensim.models.keyedvectors.Vocab at 0x2a33cabf0a0>,
#  'забыва': <gensim.models.keyedvectors.Vocab at 0x2a33cabf100>,
#  'оперативк': <gensim.models.keyedvectors.Vocab at 0x2a33cabf160>,
#  'майкрософт': <gensim.models.keyedvectors.Vocab at 0x2a33cabf1c0>,
#  'привет': <gensim.models.keyedvectors.Vocab at 0x2a33cabf220>,
#  'откр': <gensim.models.keyedvectors.Vocab at 0x2a33cabf280>,
#  'счет': <gensim.models.keyedvectors.Vocab at 0x2a33cabf2e0>,
#  'сбербанк': <gensim.models.keyedvectors.Vocab at 0x2a33cabf340>,
#  'снима': <gensim.models.keyedvectors.Vocab at 0x2a33cabf3a0>,
#  'пробл': <gensim.models.keyedvectors.Vocab at 0x2a33cabf400>,
#  'течен': <gensim.models.keyedvectors.Vocab at 0x2a33cabf460>,
#  'час': <gensim.models.keyedvectors.Vocab at 0x2a33cabf4c0>,
#  'хот': <gensim.models.keyedvectors.Vocab at 0x2a33cabf520>,
#  'заявл': <gensim.models.keyedvectors.Vocab at 0x2a33cabf580>,
#  'счита': <gensim.models.keyedvectors.Vocab at 0x2a33cabf5e0>,
#  'единорог': <gensim.models.keyedvectors.Vocab at 0x2a33cabf640>,
#  'жизн': <gensim.models.keyedvectors.Vocab at 0x2a33cabf6a0>,
#  'встрет': <gensim.models.keyedvectors.Vocab at 0x2a33cabf700>,
#  'отмет': <gensim.models.keyedvectors.Vocab at 0x2a33cabf760>,
#  'лет': <gensim.models.keyedvectors.Vocab at 0x2a33cabf7c0>,
#  'детк': <gensim.models.keyedvectors.Vocab at 0x2a33cabf820>,
#  'ебуч': <gensim.models.keyedvectors.Vocab at 0x2a33cabf880>,
#  'https': <gensim.models.keyedvectors.Vocab at 0x2a33cabf8e0>,
#  'не': <gensim.models.keyedvectors.Vocab at 0x2a33cabf940>,
#  'автор': <gensim.models.keyedvectors.Vocab at 0x2a33cabf9a0>,
#  'маск': <gensim.models.keyedvectors.Vocab at 0x2a33cabfa00>,
#  'разрабатыва': <gensim.models.keyedvectors.Vocab at 0x2a33cabfa60>,
#  'полност': <gensim.models.keyedvectors.Vocab at 0x2a33cabfac0>,
#  'многоразов': <gensim.models.keyedvectors.Vocab at 0x2a33cabfb20>,
#  'ракет': <gensim.models.keyedvectors.Vocab at 0x2a33cabfb80>,
#  'испытыва': <gensim.models.keyedvectors.Vocab at 0x2a33cabfbe0>,
#  'бок': <gensim.models.keyedvectors.Vocab at 0x2a33cabfc40>,
#  'чик': <gensim.models.keyedvectors.Vocab at 0x2a33cabfca0>,
#  'котор': <gensim.models.keyedvectors.Vocab at 0x2a33cabfd00>,
#  'корабл': <gensim.models.keyedvectors.Vocab at 0x2a33cabfd60>,
#  'выполня': <gensim.models.keyedvectors.Vocab at 0x2a33cabfdc0>,
#  'рол': <gensim.models.keyedvectors.Vocab at 0x2a33cabfe20>,
#  'втор': <gensim.models.keyedvectors.Vocab at 0x2a33cabfe80>,
#  'ступен': <gensim.models.keyedvectors.Vocab at 0x2a33cabfee0>,
#  'предлага': <gensim.models.keyedvectors.Vocab at 0x2a33cabff40>,
#  'лезт': <gensim.models.keyedvectors.Vocab at 0x2a33cabffa0>,
#  'дубинк': <gensim.models.keyedvectors.Vocab at 0x2a33cac1040>,
#  'штраф': <gensim.models.keyedvectors.Vocab at 0x2a33cac10a0>,
#  'пок': <gensim.models.keyedvectors.Vocab at 0x2a33cac1100>,
#  'отел': <gensim.models.keyedvectors.Vocab at 0x2a33cac1160>,
#  'рук': <gensim.models.keyedvectors.Vocab at 0x2a33cac11c0>,
#  'толчк': <gensim.models.keyedvectors.Vocab at 0x2a33cac1220>,
#  'явн': <gensim.models.keyedvectors.Vocab at 0x2a33cac1280>,
#  'слив': <gensim.models.keyedvectors.Vocab at 0x2a33cac12e0>,
#  'вод': <gensim.models.keyedvectors.Vocab at 0x2a33cac1340>,
#  'душ': <gensim.models.keyedvectors.Vocab at 0x2a33cac13a0>,
#  'задума': <gensim.models.keyedvectors.Vocab at 0x2a33cac1400>,
#  'понрав': <gensim.models.keyedvectors.Vocab at 0x2a33cac1460>,
#  'строчк': <gensim.models.keyedvectors.Vocab at 0x2a33cac14c0>,
#  'гарант': <gensim.models.keyedvectors.Vocab at 0x2a33cac1520>,
#  'стопудов': <gensim.models.keyedvectors.Vocab at 0x2a33cac1580>,
#  'специальн': <gensim.models.keyedvectors.Vocab at 0x2a33cac15e0>,
#  'дела': <gensim.models.keyedvectors.Vocab at 0x2a33cac1640>,
#  'монитор': <gensim.models.keyedvectors.Vocab at 0x2a33cac16a0>,
#  'пада': <gensim.models.keyedvectors.Vocab at 0x2a33cac1700>,
#  'конча': <gensim.models.keyedvectors.Vocab at 0x2a33cac1760>,
#  'херн': <gensim.models.keyedvectors.Vocab at 0x2a33cac17c0>,
#  'превыша': <gensim.models.keyedvectors.Vocab at 0x2a33cac1820>,
#  'близк': <gensim.models.keyedvectors.Vocab at 0x2a33cac1880>,
#  'придержива': <gensim.models.keyedvectors.Vocab at 0x2a33cac18e0>,
#  'прав': <gensim.models.keyedvectors.Vocab at 0x2a33cac1940>,
#  'завтрака': <gensim.models.keyedvectors.Vocab at 0x2a33cac19a0>,
#  'иб': <gensim.models.keyedvectors.Vocab at 0x2a33cac1a00>,
#  'пью': <gensim.models.keyedvectors.Vocab at 0x2a33cac1a60>,
#  'особен': <gensim.models.keyedvectors.Vocab at 0x2a33cac1ac0>,
#  'совершен': <gensim.models.keyedvectors.Vocab at 0x2a33cac1b20>,
#  'понят': <gensim.models.keyedvectors.Vocab at 0x2a33cac1b80>,
#  'готов': <gensim.models.keyedvectors.Vocab at 0x2a33cac1be0>,
#  'ем': <gensim.models.keyedvectors.Vocab at 0x2a33cac1c40>,
#  'чипс': <gensim.models.keyedvectors.Vocab at 0x2a33cac1ca0>,
#  'колбас': <gensim.models.keyedvectors.Vocab at 0x2a33cac1d00>,
#  'ресторан': <gensim.models.keyedvectors.Vocab at 0x2a33cac1d60>,
#  'мог': <gensim.models.keyedvectors.Vocab at 0x2a33cac1dc0>,
#  'заказа': <gensim.models.keyedvectors.Vocab at 0x2a33cac1e20>,
#  'невест': <gensim.models.keyedvectors.Vocab at 0x2a33cac1e80>,
#  'интересн': <gensim.models.keyedvectors.Vocab at 0x2a33cac1ee0>,
#  'назван': <gensim.models.keyedvectors.Vocab at 0x2a33cac1f40>,
#  'беспок': <gensim.models.keyedvectors.Vocab at 0x2a33cac1fa0>,
#  'скольк': <gensim.models.keyedvectors.Vocab at 0x2a33cac2040>,
#  'масл': <gensim.models.keyedvectors.Vocab at 0x2a33cac20a0>,
#  'жир': <gensim.models.keyedvectors.Vocab at 0x2a33cac2100>,
#  'телефон': <gensim.models.keyedvectors.Vocab at 0x2a33cac2160>,
#  'книг': <gensim.models.keyedvectors.Vocab at 0x2a33cac21c0>,
#  'работ': <gensim.models.keyedvectors.Vocab at 0x2a33cac2220>,
#  'исключен': <gensim.models.keyedvectors.Vocab at 0x2a33cac2280>,
#  'прекрасн': <gensim.models.keyedvectors.Vocab at 0x2a33cac22e0>,
#  'частичн': <gensim.models.keyedvectors.Vocab at 0x2a33cac2340>,
#  'изврат': <gensim.models.keyedvectors.Vocab at 0x2a33cac23a0>,
#  'б': <gensim.models.keyedvectors.Vocab at 0x2a33cac2400>,
#  'прост': <gensim.models.keyedvectors.Vocab at 0x2a33cac2460>,
#  'ожирен': <gensim.models.keyedvectors.Vocab at 0x2a33cac24c0>,
#  'проблем': <gensim.models.keyedvectors.Vocab at 0x2a33cac2520>,
#  'гордост': <gensim.models.keyedvectors.Vocab at 0x2a33cac2580>,
#  'норвежц': <gensim.models.keyedvectors.Vocab at 0x2a33cac25e0>,
#  'обогна': <gensim.models.keyedvectors.Vocab at 0x2a33cac2640>,
#  'сарказм': <gensim.models.keyedvectors.Vocab at 0x2a33cac26a0>,
#  'охренет': <gensim.models.keyedvectors.Vocab at 0x2a33cac2700>,
#  'инкассатор': <gensim.models.keyedvectors.Vocab at 0x2a33cac2760>,
#  'пьян': <gensim.models.keyedvectors.Vocab at 0x2a33cac27c0>,
#  'оруж': <gensim.models.keyedvectors.Vocab at 0x2a33cac2820>,
#  'пздц': <gensim.models.keyedvectors.Vocab at 0x2a33cac2880>,
#  'голов': <gensim.models.keyedvectors.Vocab at 0x2a33cac28e0>,
#  'арм': <gensim.models.keyedvectors.Vocab at 0x2a33cac2940>,
#  'власт': <gensim.models.keyedvectors.Vocab at 0x2a33cac29a0>,
#  'позор': <gensim.models.keyedvectors.Vocab at 0x2a33cac2a00>,
#  'перв': <gensim.models.keyedvectors.Vocab at 0x2a33cac2a60>,
#  'миров': <gensim.models.keyedvectors.Vocab at 0x2a33cac2ac0>,
#  'войн': <gensim.models.keyedvectors.Vocab at 0x2a33cac2b20>,
#  'наплевательск': <gensim.models.keyedvectors.Vocab at 0x2a33cac2b80>,
#  'отношен': <gensim.models.keyedvectors.Vocab at 0x2a33cac2be0>,
#  'студент': <gensim.models.keyedvectors.Vocab at 0x2a33cac2c40>,
#  'постоя': <gensim.models.keyedvectors.Vocab at 0x2a33cac2ca0>,
#  'ход': <gensim.models.keyedvectors.Vocab at 0x2a33cac2d00>,
#  'религиозн': <gensim.models.keyedvectors.Vocab at 0x2a33cac2d60>,
#  'праздник': <gensim.models.keyedvectors.Vocab at 0x2a33cac2dc0>,
#  'пита': <gensim.models.keyedvectors.Vocab at 0x2a33cac2e20>,
#  'жела': <gensim.models.keyedvectors.Vocab at 0x2a33cac2e80>,
#  'пил': <gensim.models.keyedvectors.Vocab at 0x2a33cac2ee0>,
#  'ча': <gensim.models.keyedvectors.Vocab at 0x2a33cac2f40>,
#  'шарик': <gensim.models.keyedvectors.Vocab at 0x2a33cac2fa0>,
#  'сок': <gensim.models.keyedvectors.Vocab at 0x2a33cac4040>,
#  'знаком': <gensim.models.keyedvectors.Vocab at 0x2a33cac40a0>,
#  'гост': <gensim.models.keyedvectors.Vocab at 0x2a33cac4100>,
#  'вмест': <gensim.models.keyedvectors.Vocab at 0x2a33cac4160>,
#  'некуд': <gensim.models.keyedvectors.Vocab at 0x2a33cac41c0>,
#  'человек': <gensim.models.keyedvectors.Vocab at 0x2a33cac4220>,
#  'област': <gensim.models.keyedvectors.Vocab at 0x2a33cac4280>,
#  'разда': <gensim.models.keyedvectors.Vocab at 0x2a33cac42e0>,
#  'применя': <gensim.models.keyedvectors.Vocab at 0x2a33cac4340>,
#  'совместн': <gensim.models.keyedvectors.Vocab at 0x2a33cac43a0>,
#  'автомат': <gensim.models.keyedvectors.Vocab at 0x2a33cac4400>,
#  'он': <gensim.models.keyedvectors.Vocab at 0x2a33cac4460>,
#  'защища': <gensim.models.keyedvectors.Vocab at 0x2a33cac44c0>,
#  'перегрузк': <gensim.models.keyedvectors.Vocab at 0x2a33cac4520>,
#  'объединя': <gensim.models.keyedvectors.Vocab at 0x2a33cac4580>,
#  'функц': <gensim.models.keyedvectors.Vocab at 0x2a33cac45e0>,
#  'уз': <gensim.models.keyedvectors.Vocab at 0x2a33cac4640>,
#  'ав': <gensim.models.keyedvectors.Vocab at 0x2a33cac46a0>,
#  'деньг': <gensim.models.keyedvectors.Vocab at 0x2a33cac4700>,
#  'билет': <gensim.models.keyedvectors.Vocab at 0x2a33cac4760>,
#  'дава': <gensim.models.keyedvectors.Vocab at 0x2a33cac47c0>,
#  'пошл': <gensim.models.keyedvectors.Vocab at 0x2a33cac4820>,
#  'нах': <gensim.models.keyedvectors.Vocab at 0x2a33cac4880>,
#  'сук': <gensim.models.keyedvectors.Vocab at 0x2a33cac48e0>,
#  'подстав': <gensim.models.keyedvectors.Vocab at 0x2a33cac4940>,
#  'мед': <gensim.models.keyedvectors.Vocab at 0x2a33cac49a0>,
#  'каза': <gensim.models.keyedvectors.Vocab at 0x2a33cac4a00>,
#  'так': <gensim.models.keyedvectors.Vocab at 0x2a33cac4a60>,
#  'твар': <gensim.models.keyedvectors.Vocab at 0x2a33cac4ac0>,
#  'уч': <gensim.models.keyedvectors.Vocab at 0x2a33cac4b20>,
#  'дальш': <gensim.models.keyedvectors.Vocab at 0x2a33cac4b80>,
#  'мир': <gensim.models.keyedvectors.Vocab at 0x2a33cac4be0>,
#  'будут': <gensim.models.keyedvectors.Vocab at 0x2a33cac4c40>,
#  'начист': <gensim.models.keyedvectors.Vocab at 0x2a33cac4ca0>,
#  'профилактик': <gensim.models.keyedvectors.Vocab at 0x2a33cac4d00>,
#  'те': <gensim.models.keyedvectors.Vocab at 0x2a33cac4d60>,
#  'говор': <gensim.models.keyedvectors.Vocab at 0x2a33cac4dc0>,
#  'баб': <gensim.models.keyedvectors.Vocab at 0x2a33cac4e20>,
#  'бит': <gensim.models.keyedvectors.Vocab at 0x2a33cac4e80>,
#  'поигра': <gensim.models.keyedvectors.Vocab at 0x2a33cac4ee0>,
#  'самоуважен': <gensim.models.keyedvectors.Vocab at 0x2a33cac4f40>,
#  'слабохарактерн': <gensim.models.keyedvectors.Vocab at 0x2a33cac4fa0>,
#  'могут': <gensim.models.keyedvectors.Vocab at 0x2a33cac6040>,
#  'соб': <gensim.models.keyedvectors.Vocab at 0x2a33cac60a0>,
#  'поконч': <gensim.models.keyedvectors.Vocab at 0x2a33cac6100>,
#  'разок': <gensim.models.keyedvectors.Vocab at 0x2a33cac6160>,
#  'лишн': <gensim.models.keyedvectors.Vocab at 0x2a33cac61c0>,
#  'психик': <gensim.models.keyedvectors.Vocab at 0x2a33cac6220>,
#  'некотор': <gensim.models.keyedvectors.Vocab at 0x2a33cac6280>,
#  'обидн': <gensim.models.keyedvectors.Vocab at 0x2a33cac62e0>,
#  'жит': <gensim.models.keyedvectors.Vocab at 0x2a33cac6340>,
#  'хран': <gensim.models.keyedvectors.Vocab at 0x2a33cac63a0>,
#  'господ': <gensim.models.keyedvectors.Vocab at 0x2a33cac6400>,
#  'брат': <gensim.models.keyedvectors.Vocab at 0x2a33cac6460>,
#  'русск': <gensim.models.keyedvectors.Vocab at 0x2a33cac64c0>,
#  'массов': <gensim.models.keyedvectors.Vocab at 0x2a33cac6520>,
#  'специализирова': <gensim.models.keyedvectors.Vocab at 0x2a33cac6580>,
#  'магазин': <gensim.models.keyedvectors.Vocab at 0x2a33cac65e0>,
#  'всяк': <gensim.models.keyedvectors.Vocab at 0x2a33cac6640>,
#  'прикуп': <gensim.models.keyedvectors.Vocab at 0x2a33cac66a0>,
#  'похож': <gensim.models.keyedvectors.Vocab at 0x2a33cac6700>,
#  'камер': <gensim.models.keyedvectors.Vocab at 0x2a33cac6760>,
#  'пыток': <gensim.models.keyedvectors.Vocab at 0x2a33cac67c0>,
#  'кров': <gensim.models.keyedvectors.Vocab at 0x2a33cac6820>,
#  'предусмотр': <gensim.models.keyedvectors.Vocab at 0x2a33cac6880>,
#  'взросл': <gensim.models.keyedvectors.Vocab at 0x2a33cac68e0>,
#  'задолба': <gensim.models.keyedvectors.Vocab at 0x2a33cac6940>,
#  'везд': <gensim.models.keyedvectors.Vocab at 0x2a33cac69a0>,
#  'раньш': <gensim.models.keyedvectors.Vocab at 0x2a33cac6a00>,
#  'гомосексуалист': <gensim.models.keyedvectors.Vocab at 0x2a33cac6a60>,
#  'относ': <gensim.models.keyedvectors.Vocab at 0x2a33cac6ac0>,
#  'никак': <gensim.models.keyedvectors.Vocab at 0x2a33cac6b20>,
#  'юмор': <gensim.models.keyedvectors.Vocab at 0x2a33cac6b80>,
#  'активн': <gensim.models.keyedvectors.Vocab at 0x2a33cac6be0>,
#  'культур': <gensim.models.keyedvectors.Vocab at 0x2a33cac6c40>,
#  'демонстрац': <gensim.models.keyedvectors.Vocab at 0x2a33cac6ca0>,
#  'кром': <gensim.models.keyedvectors.Vocab at 0x2a33cac6d00>,
#  'раздражен': <gensim.models.keyedvectors.Vocab at 0x2a33cac6d60>,
#  'вызыва': <gensim.models.keyedvectors.Vocab at 0x2a33cac6dc0>,
#  'товарищ': <gensim.models.keyedvectors.Vocab at 0x2a33cac6e20>,
#  'миш': <gensim.models.keyedvectors.Vocab at 0x2a33cac6e80>,
#  'друз': <gensim.models.keyedvectors.Vocab at 0x2a33cac6ee0>,
#  'ху': <gensim.models.keyedvectors.Vocab at 0x2a33cac6f40>,
#  'муз': <gensim.models.keyedvectors.Vocab at 0x2a33cac6fa0>,
#  'имет': <gensim.models.keyedvectors.Vocab at 0x2a33cac8040>,
#  'сомнительн': <gensim.models.keyedvectors.Vocab at 0x2a33cac80a0>,
#  'эффект': <gensim.models.keyedvectors.Vocab at 0x2a33cac8100>,
#  'физическ': <gensim.models.keyedvectors.Vocab at 0x2a33cac8160>,
#  'протяжен': <gensim.models.keyedvectors.Vocab at 0x2a33cac81c0>,
#  'дня': <gensim.models.keyedvectors.Vocab at 0x2a33cac8220>,
#  'сможет': <gensim.models.keyedvectors.Vocab at 0x2a33cac8280>,
#  'набра': <gensim.models.keyedvectors.Vocab at 0x2a33cac82e0>,
#  'вес': <gensim.models.keyedvectors.Vocab at 0x2a33cac8340>,
#  'будет': <gensim.models.keyedvectors.Vocab at 0x2a33cac83a0>,
#  'сжига': <gensim.models.keyedvectors.Vocab at 0x2a33cac8400>,
#  'закидыва': <gensim.models.keyedvectors.Vocab at 0x2a33cac8460>,
#  'офис': <gensim.models.keyedvectors.Vocab at 0x2a33cac84c0>,
#  'приседа': <gensim.models.keyedvectors.Vocab at 0x2a33cac8520>,
#  'подход': <gensim.models.keyedvectors.Vocab at 0x2a33cac8580>,
#  'кос': <gensim.models.keyedvectors.Vocab at 0x2a33cac85e0>,
#  'скаж': <gensim.models.keyedvectors.Vocab at 0x2a33cac8640>,
#  'врач': <gensim.models.keyedvectors.Vocab at 0x2a33cac86a0>,
#  'строг': <gensim.models.keyedvectors.Vocab at 0x2a33cac8700>,
#  'рекомендова': <gensim.models.keyedvectors.Vocab at 0x2a33cac8760>,
#  'таблетк': <gensim.models.keyedvectors.Vocab at 0x2a33cac87c0>,
#  'заб': <gensim.models.keyedvectors.Vocab at 0x2a33cac8820>,
#  'приня': <gensim.models.keyedvectors.Vocab at 0x2a33cac8880>,
#  'скриншот': <gensim.models.keyedvectors.Vocab at 0x2a33cac88e0>,
#  'наверн': <gensim.models.keyedvectors.Vocab at 0x2a33cac8940>,
#  'вел': <gensim.models.keyedvectors.Vocab at 0x2a33cac89a0>,
#  'склад': <gensim.models.keyedvectors.Vocab at 0x2a33cac8a00>,
#  'остав': <gensim.models.keyedvectors.Vocab at 0x2a33cac8a60>,
#  'забра': <gensim.models.keyedvectors.Vocab at 0x2a33cac8ac0>,
#  'предприят': <gensim.models.keyedvectors.Vocab at 0x2a33cac8b20>,
#  'развалива': <gensim.models.keyedvectors.Vocab at 0x2a33cac8b80>,
#  'дубин': <gensim.models.keyedvectors.Vocab at 0x2a33cac8be0>,
#  'дурак': <gensim.models.keyedvectors.Vocab at 0x2a33cac8c40>,
#  'нищ': <gensim.models.keyedvectors.Vocab at 0x2a33cac8ca0>,
#  'армен': <gensim.models.keyedvectors.Vocab at 0x2a33cac8d00>,
#  'еха': <gensim.models.keyedvectors.Vocab at 0x2a33cac8d60>,
#  'умира': <gensim.models.keyedvectors.Vocab at 0x2a33cac8dc0>,
#  'караб': <gensim.models.keyedvectors.Vocab at 0x2a33cac8e20>,
#  'мраз': <gensim.models.keyedvectors.Vocab at 0x2a33cac8e80>,
#  'лен': <gensim.models.keyedvectors.Vocab at 0x2a33cac8ee0>,
#  'жен': <gensim.models.keyedvectors.Vocab at 0x2a33cac8f40>,
#  'сапог': <gensim.models.keyedvectors.Vocab at 0x2a33cac8fa0>,
#  'покупа': <gensim.models.keyedvectors.Vocab at 0x2a33caca040>,
#  'цыганк': <gensim.models.keyedvectors.Vocab at 0x2a33caca0a0>,
#  'показа': <gensim.models.keyedvectors.Vocab at 0x2a33caca100>,
#  'мелоч': <gensim.models.keyedvectors.Vocab at 0x2a33caca160>,
#  'бумажк': <gensim.models.keyedvectors.Vocab at 0x2a33caca1c0>,
#  'попыта': <gensim.models.keyedvectors.Vocab at 0x2a33caca220>,
#  'рубл': <gensim.models.keyedvectors.Vocab at 0x2a33caca280>,
#  'сумм': <gensim.models.keyedvectors.Vocab at 0x2a33caca2e0>,
#  'заяв': <gensim.models.keyedvectors.Vocab at 0x2a33caca340>,
#  'дайт': <gensim.models.keyedvectors.Vocab at 0x2a33caca3a0>,
#  'сдач': <gensim.models.keyedvectors.Vocab at 0x2a33caca400>,
#  'вопрос': <gensim.models.keyedvectors.Vocab at 0x2a33caca460>,
#  'нич': <gensim.models.keyedvectors.Vocab at 0x2a33caca4c0>,
#  'треснет': <gensim.models.keyedvectors.Vocab at 0x2a33caca520>,
#  'обидел': <gensim.models.keyedvectors.Vocab at 0x2a33caca580>,
#  'ушл': <gensim.models.keyedvectors.Vocab at 0x2a33caca5e0>,
#  'рассказа': <gensim.models.keyedvectors.Vocab at 0x2a33caca640>,
#  'днях': <gensim.models.keyedvectors.Vocab at 0x2a33caca6a0>,
#  'пришл': <gensim.models.keyedvectors.Vocab at 0x2a33caca700>,
#  'выбра': <gensim.models.keyedvectors.Vocab at 0x2a33caca760>,
#  'перчатк': <gensim.models.keyedvectors.Vocab at 0x2a33caca7c0>,
#  'спрята': <gensim.models.keyedvectors.Vocab at 0x2a33caca820>,
#  'карма': <gensim.models.keyedvectors.Vocab at 0x2a33caca880>,
#  'труд': <gensim.models.keyedvectors.Vocab at 0x2a33caca8e0>,
#  'полож': <gensim.models.keyedvectors.Vocab at 0x2a33caca940>,
#  'пожал': <gensim.models.keyedvectors.Vocab at 0x2a33caca9a0>,
#  'начальств': <gensim.models.keyedvectors.Vocab at 0x2a33cacaa00>,
#  'горд': <gensim.models.keyedvectors.Vocab at 0x2a33cacaa60>,
#  'удал': <gensim.models.keyedvectors.Vocab at 0x2a33cacaac0>,
#  'написа': <gensim.models.keyedvectors.Vocab at 0x2a33cacab20>,
#  'пост': <gensim.models.keyedvectors.Vocab at 0x2a33cacab80>,
#  'тем': <gensim.models.keyedvectors.Vocab at 0x2a33cacabe0>,
#  'опубликова': <gensim.models.keyedvectors.Vocab at 0x2a33cacac40>,
#  'рад': <gensim.models.keyedvectors.Vocab at 0x2a33cacaca0>,
#  'просьб': <gensim.models.keyedvectors.Vocab at 0x2a33cacad00>,
#  'услыша': <gensim.models.keyedvectors.Vocab at 0x2a33cacad60>,
#  'арт': <gensim.models.keyedvectors.Vocab at 0x2a33cacadc0>,
#  'вид': <gensim.models.keyedvectors.Vocab at 0x2a33cacae20>,
#  'связ': <gensim.models.keyedvectors.Vocab at 0x2a33cacae80>,
#  'ден': <gensim.models.keyedvectors.Vocab at 0x2a33cacaee0>,
#  'фиксир': <gensim.models.keyedvectors.Vocab at 0x2a33cacaf40>,
#  'заболевш': <gensim.models.keyedvectors.Vocab at 0x2a33cacafa0>,
#  'хорош': <gensim.models.keyedvectors.Vocab at 0x2a33cacc040>,
#  'девушк': <gensim.models.keyedvectors.Vocab at 0x2a33cacc0a0>,
#  'ладн': <gensim.models.keyedvectors.Vocab at 0x2a33cacc100>,
#  'пуст': <gensim.models.keyedvectors.Vocab at 0x2a33cacc160>,
#  'жадн': <gensim.models.keyedvectors.Vocab at 0x2a33cacc1c0>,
#  'девушек': <gensim.models.keyedvectors.Vocab at 0x2a33cacc220>,
#  'имен': <gensim.models.keyedvectors.Vocab at 0x2a33cacc280>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x2a33cacc2e0>,
#  'умудря': <gensim.models.keyedvectors.Vocab at 0x2a33cacc340>,
#  'станов': <gensim.models.keyedvectors.Vocab at 0x2a33cacc3a0>,
#  'стар': <gensim.models.keyedvectors.Vocab at 0x2a33cacc400>,
#  'пердун': <gensim.models.keyedvectors.Vocab at 0x2a33cacc460>,
#  'молод': <gensim.models.keyedvectors.Vocab at 0x2a33cacc4c0>,
#  'возраст': <gensim.models.keyedvectors.Vocab at 0x2a33cacc520>,
#  'комментатор': <gensim.models.keyedvectors.Vocab at 0x2a33cacc580>,
#  'психическ': <gensim.models.keyedvectors.Vocab at 0x2a33cacc5e0>,
#  'отклонен': <gensim.models.keyedvectors.Vocab at 0x2a33cacc640>,
#  'больн': <gensim.models.keyedvectors.Vocab at 0x2a33cacc6a0>,
#  'поня': <gensim.models.keyedvectors.Vocab at 0x2a33cacc700>,
#  'решительн': <gensim.models.keyedvectors.Vocab at 0x2a33cacc760>,
#  'охуен': <gensim.models.keyedvectors.Vocab at 0x2a33cacc7c0>,
#  'здоров': <gensim.models.keyedvectors.Vocab at 0x2a33cacc820>,
#  'отсутств': <gensim.models.keyedvectors.Vocab at 0x2a33cacc880>,
#  'эмоц': <gensim.models.keyedvectors.Vocab at 0x2a33cacc8e0>,
#  'появ': <gensim.models.keyedvectors.Vocab at 0x2a33cacc940>,
#  'гас': <gensim.models.keyedvectors.Vocab at 0x2a33cacc9a0>,
#  'вычисл': <gensim.models.keyedvectors.Vocab at 0x2a33cacca00>,
#  'нож': <gensim.models.keyedvectors.Vocab at 0x2a33cacca60>,
#  'накладыва': <gensim.models.keyedvectors.Vocab at 0x2a33caccac0>,
#  'тарелк': <gensim.models.keyedvectors.Vocab at 0x2a33caccb20>,
#  'снимок': <gensim.models.keyedvectors.Vocab at 0x2a33caccb80>,
#  'линз': <gensim.models.keyedvectors.Vocab at 0x2a33caccbe0>,
#  'добавьт': <gensim.models.keyedvectors.Vocab at 0x2a33caccc40>,
#  'наглядн': <gensim.models.keyedvectors.Vocab at 0x2a33caccca0>,
#  'сравнен': <gensim.models.keyedvectors.Vocab at 0x2a33caccd00>,
#  'попроб': <gensim.models.keyedvectors.Vocab at 0x2a33caccd60>,
#  'всем': <gensim.models.keyedvectors.Vocab at 0x2a33caccdc0>,
#  'извилин': <gensim.models.keyedvectors.Vocab at 0x2a33cacce20>,
#  'подума': <gensim.models.keyedvectors.Vocab at 0x2a33cacce80>,
#  'недавн': <gensim.models.keyedvectors.Vocab at 0x2a33caccee0>,
#  'укус': <gensim.models.keyedvectors.Vocab at 0x2a33caccf40>,
#  'клещ': <gensim.models.keyedvectors.Vocab at 0x2a33caccfa0>,
#  'оторва': <gensim.models.keyedvectors.Vocab at 0x2a33cace040>,
#  'интернет': <gensim.models.keyedvectors.Vocab at 0x2a33cace0a0>,
#  'прочита': <gensim.models.keyedvectors.Vocab at 0x2a33cace100>,
#  'чеснок': <gensim.models.keyedvectors.Vocab at 0x2a33cace160>,
#  'сожра': <gensim.models.keyedvectors.Vocab at 0x2a33cace1c0>,
#  'головк': <gensim.models.keyedvectors.Vocab at 0x2a33cace220>,
#  'прошл': <gensim.models.keyedvectors.Vocab at 0x2a33cace280>,
#  'ниху': <gensim.models.keyedvectors.Vocab at 0x2a33cace2e0>,
#  'осложнен': <gensim.models.keyedvectors.Vocab at 0x2a33cace340>,
#  'мозг': <gensim.models.keyedvectors.Vocab at 0x2a33cace3a0>,
#  'дал': <gensim.models.keyedvectors.Vocab at 0x2a33cace400>,
#  'как': <gensim.models.keyedvectors.Vocab at 0x2a33cace460>,
#  'дич': <gensim.models.keyedvectors.Vocab at 0x2a33cace4c0>,
#  'несет': <gensim.models.keyedvectors.Vocab at 0x2a33cace520>,
#  'буд': <gensim.models.keyedvectors.Vocab at 0x2a33cace580>,
#  'интерфейс': <gensim.models.keyedvectors.Vocab at 0x2a33cace5e0>,
#  'мид': <gensim.models.keyedvectors.Vocab at 0x2a33cace640>,
#  'пох': <gensim.models.keyedvectors.Vocab at 0x2a33cace6a0>,
#  'дива': <gensim.models.keyedvectors.Vocab at 0x2a33cace700>,
#  'аналитик': <gensim.models.keyedvectors.Vocab at 0x2a33cace760>,
#  'хочеш': <gensim.models.keyedvectors.Vocab at 0x2a33cace7c0>,
#  'пашиня': <gensim.models.keyedvectors.Vocab at 0x2a33cace820>,
#  'долж': <gensim.models.keyedvectors.Vocab at 0x2a33cace880>,
#  'заран': <gensim.models.keyedvectors.Vocab at 0x2a33cace8e0>,
#  'нападен': <gensim.models.keyedvectors.Vocab at 0x2a33cace940>,
#  'соглас': <gensim.models.keyedvectors.Vocab at 0x2a33cace9a0>,
#  'армян': <gensim.models.keyedvectors.Vocab at 0x2a33cacea00>,
#  'прос': <gensim.models.keyedvectors.Vocab at 0x2a33cacea60>,
#  'убива': <gensim.models.keyedvectors.Vocab at 0x2a33caceac0>,
#  'земл': <gensim.models.keyedvectors.Vocab at 0x2a33caceb20>,
#  'туд': <gensim.models.keyedvectors.Vocab at 0x2a33caceb80>,
#  'едут': <gensim.models.keyedvectors.Vocab at 0x2a33cacebe0>,
#  'воева': <gensim.models.keyedvectors.Vocab at 0x2a33cacec40>,
#  'ног': <gensim.models.keyedvectors.Vocab at 0x2a33caceca0>,
#  'вся': <gensim.models.keyedvectors.Vocab at 0x2a33caced00>,
#  'кост': <gensim.models.keyedvectors.Vocab at 0x2a33caced60>,
#  'наруж': <gensim.models.keyedvectors.Vocab at 0x2a33cacedc0>,
#  'кожух': <gensim.models.keyedvectors.Vocab at 0x2a33cacee20>,
#  'ощущен': <gensim.models.keyedvectors.Vocab at 0x2a33cacee80>,
#  'грустн': <gensim.models.keyedvectors.Vocab at 0x2a33caceee0>,
#  'пута': <gensim.models.keyedvectors.Vocab at 0x2a33cacef40>,
#  'выражен': <gensim.models.keyedvectors.Vocab at 0x2a33cacefa0>,
#  'уравнен': <gensim.models.keyedvectors.Vocab at 0x2a33cad0040>,
#  'докажут': <gensim.models.keyedvectors.Vocab at 0x2a33cad00a0>,
#  'умер': <gensim.models.keyedvectors.Vocab at 0x2a33cad0100>,
#  'повед': <gensim.models.keyedvectors.Vocab at 0x2a33cad0160>,
#  'подва': <gensim.models.keyedvectors.Vocab at 0x2a33cad01c0>,
#  'намекнул': <gensim.models.keyedvectors.Vocab at 0x2a33cad0220>,
#  'раз': <gensim.models.keyedvectors.Vocab at 0x2a33cad0280>,
#  'дежурств': <gensim.models.keyedvectors.Vocab at 0x2a33cad02e0>,
#  'форм': <gensim.models.keyedvectors.Vocab at 0x2a33cad0340>,
#  'карет': <gensim.models.keyedvectors.Vocab at 0x2a33cad03a0>,
#  'смп': <gensim.models.keyedvectors.Vocab at 0x2a33cad0400>,
#  'шибк': <gensim.models.keyedvectors.Vocab at 0x2a33cad0460>,
#  'допуск': <gensim.models.keyedvectors.Vocab at 0x2a33cad04c0>,
#  'погрешн': <gensim.models.keyedvectors.Vocab at 0x2a33cad0520>,
#  'запил': <gensim.models.keyedvectors.Vocab at 0x2a33cad0580>,
#  'задержа': <gensim.models.keyedvectors.Vocab at 0x2a33cad05e0>,
#  'управля': <gensim.models.keyedvectors.Vocab at 0x2a33cad0640>,
#  'кукл': <gensim.models.keyedvectors.Vocab at 0x2a33cad06a0>,
#  'весел': <gensim.models.keyedvectors.Vocab at 0x2a33cad0700>,
#  'дет': <gensim.models.keyedvectors.Vocab at 0x2a33cad0760>,
#  'прям': <gensim.models.keyedvectors.Vocab at 0x2a33cad07c0>,
#  'смотр': <gensim.models.keyedvectors.Vocab at 0x2a33cad0820>,
#  'лукашенк': <gensim.models.keyedvectors.Vocab at 0x2a33cad0880>,
#  'задержива': <gensim.models.keyedvectors.Vocab at 0x2a33cad08e0>,
#  'президент': <gensim.models.keyedvectors.Vocab at 0x2a33cad0940>,
#  'миг': <gensim.models.keyedvectors.Vocab at 0x2a33cad09a0>,
#  'навел': <gensim.models.keyedvectors.Vocab at 0x2a33cad0a00>,
#  'порядок': <gensim.models.keyedvectors.Vocab at 0x2a33cad0a60>,
#  'занима': <gensim.models.keyedvectors.Vocab at 0x2a33cad0ac0>,
#  'публичн': <gensim.models.keyedvectors.Vocab at 0x2a33cad0b20>,
#  'отда': <gensim.models.keyedvectors.Vocab at 0x2a33cad0b80>,
#  'забер': <gensim.models.keyedvectors.Vocab at 0x2a33cad0be0>,
#  'конц': <gensim.models.keyedvectors.Vocab at 0x2a33cad0c40>,
#  'нашел': <gensim.models.keyedvectors.Vocab at 0x2a33cad0ca0>,
#  'подпол': <gensim.models.keyedvectors.Vocab at 0x2a33cad0d00>,
#  'умерш': <gensim.models.keyedvectors.Vocab at 0x2a33cad0d60>,
#  'дед': <gensim.models.keyedvectors.Vocab at 0x2a33cad0dc0>,
#  'цел': <gensim.models.keyedvectors.Vocab at 0x2a33cad0e20>,
#  'состоян': <gensim.models.keyedvectors.Vocab at 0x2a33cad0e80>,
#  'удочк': <gensim.models.keyedvectors.Vocab at 0x2a33cad0ee0>,
#  'спиннинг': <gensim.models.keyedvectors.Vocab at 0x2a33cad0f40>,
#  'телескоп': <gensim.models.keyedvectors.Vocab at 0x2a33cad0fa0>,
#  'катушк': <gensim.models.keyedvectors.Vocab at 0x2a33cad2040>,
#  'закрыт': <gensim.models.keyedvectors.Vocab at 0x2a33cad20a0>,
#  'зимн': <gensim.models.keyedvectors.Vocab at 0x2a33cad2100>,
#  'рыбалк': <gensim.models.keyedvectors.Vocab at 0x2a33cad2160>,
#  'стал': <gensim.models.keyedvectors.Vocab at 0x2a33cad21c0>,
#  'рыбак': <gensim.models.keyedvectors.Vocab at 0x2a33cad2220>,
#  'детств': <gensim.models.keyedvectors.Vocab at 0x2a33cad2280>,
#  'японск': <gensim.models.keyedvectors.Vocab at 0x2a33cad22e0>,
#  'леск': <gensim.models.keyedvectors.Vocab at 0x2a33cad2340>,
#  'минимум': <gensim.models.keyedvectors.Vocab at 0x2a33cad23a0>,
#  'пролежа': <gensim.models.keyedvectors.Vocab at 0x2a33cad2400>,
#  'нескольк': <gensim.models.keyedvectors.Vocab at 0x2a33cad2460>,
#  'прочн': <gensim.models.keyedvectors.Vocab at 0x2a33cad24c0>,
#  'салфетк': <gensim.models.keyedvectors.Vocab at 0x2a33cad2520>,
#  'точ': <gensim.models.keyedvectors.Vocab at 0x2a33cad2580>,
#  'рекламн': <gensim.models.keyedvectors.Vocab at 0x2a33cad25e0>,
#  'картинк': <gensim.models.keyedvectors.Vocab at 0x2a33cad2640>,
#  'людьм': <gensim.models.keyedvectors.Vocab at 0x2a33cad26a0>,
#  'друг': <gensim.models.keyedvectors.Vocab at 0x2a33cad2700>,
#  'национальн': <gensim.models.keyedvectors.Vocab at 0x2a33cad2760>,
#  'смеша': <gensim.models.keyedvectors.Vocab at 0x2a33cad27c0>,
#  'догадыва': <gensim.models.keyedvectors.Vocab at 0x2a33cad2820>,
#  'ответ': <gensim.models.keyedvectors.Vocab at 0x2a33cad2880>,
#  'месяц': <gensim.models.keyedvectors.Vocab at 0x2a33cad28e0>,
#  'рф': <gensim.models.keyedvectors.Vocab at 0x2a33cad2940>,
#  'запуст': <gensim.models.keyedvectors.Vocab at 0x2a33cad29a0>,
#  'спотифа': <gensim.models.keyedvectors.Vocab at 0x2a33cad2a00>,
#  'очеред': <gensim.models.keyedvectors.Vocab at 0x2a33cad2a60>,
#  'бесплатн': <gensim.models.keyedvectors.Vocab at 0x2a33cad2ac0>,
#  'екатерин': <gensim.models.keyedvectors.Vocab at 0x2a33cad2b20>,
#  'велик': <gensim.models.keyedvectors.Vocab at 0x2a33cad2b80>,
#  'начина': <gensim.models.keyedvectors.Vocab at 0x2a33cad2be0>,
#  'сет': <gensim.models.keyedvectors.Vocab at 0x2a33cad2c40>,
#  'выкладыва': <gensim.models.keyedvectors.Vocab at 0x2a33cad2ca0>,
#  'счаст': <gensim.models.keyedvectors.Vocab at 0x2a33cad2d00>,
#  'табуретк': <gensim.models.keyedvectors.Vocab at 0x2a33cad2d60>,
#  'кажет': <gensim.models.keyedvectors.Vocab at 0x2a33cad2dc0>,
#  'джек': <gensim.models.keyedvectors.Vocab at 0x2a33cad2e20>,
#  'блэк': <gensim.models.keyedvectors.Vocab at 0x2a33cad2e80>,
#  'фу': <gensim.models.keyedvectors.Vocab at 0x2a33cad2ee0>,
#  'скрут': <gensim.models.keyedvectors.Vocab at 0x2a33cad2f40>,
#  'плед': <gensim.models.keyedvectors.Vocab at 0x2a33cad2fa0>,
#  'боя': <gensim.models.keyedvectors.Vocab at 0x2a33cad4040>,
#  'дик': <gensim.models.keyedvectors.Vocab at 0x2a33cad40a0>,
#  'происход': <gensim.models.keyedvectors.Vocab at 0x2a33cad4100>,
#  'замечательн': <gensim.models.keyedvectors.Vocab at 0x2a33cad4160>,
#  'отсоса': <gensim.models.keyedvectors.Vocab at 0x2a33cad41c0>,
#  'посла': <gensim.models.keyedvectors.Vocab at 0x2a33cad4220>,
#  'идеальн': <gensim.models.keyedvectors.Vocab at 0x2a33cad4280>,
#  'матер': <gensim.models.keyedvectors.Vocab at 0x2a33cad42e0>,
#  'мо': <gensim.models.keyedvectors.Vocab at 0x2a33cad4340>,
#  'коллег': <gensim.models.keyedvectors.Vocab at 0x2a33cad43a0>,
#  'извин': <gensim.models.keyedvectors.Vocab at 0x2a33cad4400>,
#  'поперл': <gensim.models.keyedvectors.Vocab at 0x2a33cad4460>,
#  'рожден': <gensim.models.keyedvectors.Vocab at 0x2a33cad44c0>,
#  'сред': <gensim.models.keyedvectors.Vocab at 0x2a33cad4520>,
#  'женщин': <gensim.models.keyedvectors.Vocab at 0x2a33cad4580>,
#  'прилета': <gensim.models.keyedvectors.Vocab at 0x2a33cad45e0>,
#  'севш': <gensim.models.keyedvectors.Vocab at 0x2a33cad4640>,
#  'самоизоляц': <gensim.models.keyedvectors.Vocab at 0x2a33cad46a0>,
#  'зараз': <gensim.models.keyedvectors.Vocab at 0x2a33cad4700>,
#  'корон': <gensim.models.keyedvectors.Vocab at 0x2a33cad4760>,
#  'та': <gensim.models.keyedvectors.Vocab at 0x2a33cad47c0>,
#  'померл': <gensim.models.keyedvectors.Vocab at 0x2a33cad4820>,
#  'ковид': <gensim.models.keyedvectors.Vocab at 0x2a33cad4880>,
#  'ссы': <gensim.models.keyedvectors.Vocab at 0x2a33cad48e0>,
#  'вирус': <gensim.models.keyedvectors.Vocab at 0x2a33cad4940>,
#  'начал': <gensim.models.keyedvectors.Vocab at 0x2a33cad49a0>,
#  'адекватн': <gensim.models.keyedvectors.Vocab at 0x2a33cad4a00>,
#  'об': <gensim.models.keyedvectors.Vocab at 0x2a33cad4a60>,
#  'реч': <gensim.models.keyedvectors.Vocab at 0x2a33cad4ac0>,
#  'степен': <gensim.models.keyedvectors.Vocab at 0x2a33cad4b20>,
#  'рват': <gensim.models.keyedvectors.Vocab at 0x2a33cad4b80>,
#  'вои^': <gensim.models.keyedvectors.Vocab at 0x2a33cad4be0>,
#  'одобря': <gensim.models.keyedvectors.Vocab at 0x2a33cad4c40>,
#  'местн': <gensim.models.keyedvectors.Vocab at 0x2a33cad4ca0>,
#  'нацист': <gensim.models.keyedvectors.Vocab at 0x2a33cad4d00>,
#  'угнета': <gensim.models.keyedvectors.Vocab at 0x2a33cad4d60>,
#  'русскоязычн': <gensim.models.keyedvectors.Vocab at 0x2a33cad4dc0>,
#  'населен': <gensim.models.keyedvectors.Vocab at 0x2a33cad4e20>,
#  'ведет': <gensim.models.keyedvectors.Vocab at 0x2a33cad4e80>,
#  'последовательн': <gensim.models.keyedvectors.Vocab at 0x2a33cad4ee0>,
#  'враг': <gensim.models.keyedvectors.Vocab at 0x2a33cad4f40>,
#  'том': <gensim.models.keyedvectors.Vocab at 0x2a33cad4fa0>,
#  'дружб': <gensim.models.keyedvectors.Vocab at 0x2a33cad6040>,
#  'мальчик': <gensim.models.keyedvectors.Vocab at 0x2a33cad60a0>,
#  'пособ': <gensim.models.keyedvectors.Vocab at 0x2a33cad6100>,
#  'повер': <gensim.models.keyedvectors.Vocab at 0x2a33cad6160>,
#  'тег': <gensim.models.keyedvectors.Vocab at 0x2a33cad61c0>,
#  'регулярн': <gensim.models.keyedvectors.Vocab at 0x2a33cad6220>,
#  'пар': <gensim.models.keyedvectors.Vocab at 0x2a33cad6280>,
#  'недел': <gensim.models.keyedvectors.Vocab at 0x2a33cad62e0>,
#  'вывалива': <gensim.models.keyedvectors.Vocab at 0x2a33cad6340>,
#  'радост': <gensim.models.keyedvectors.Vocab at 0x2a33cad63a0>,
#  'съезд': <gensim.models.keyedvectors.Vocab at 0x2a33cad6400>,
#  'вна': <gensim.models.keyedvectors.Vocab at 0x2a33cad6460>,
#  'украин': <gensim.models.keyedvectors.Vocab at 0x2a33cad64c0>,
#  'срочн': <gensim.models.keyedvectors.Vocab at 0x2a33cad6520>,
#  'дел': <gensim.models.keyedvectors.Vocab at 0x2a33cad6580>,
#  'навест': <gensim.models.keyedvectors.Vocab at 0x2a33cad65e0>,
#  'сестр': <gensim.models.keyedvectors.Vocab at 0x2a33cad6640>,
#  'любов': <gensim.models.keyedvectors.Vocab at 0x2a33cad66a0>,
#  'проеха': <gensim.models.keyedvectors.Vocab at 0x2a33cad6700>,
#  'границ': <gensim.models.keyedvectors.Vocab at 0x2a33cad6760>,
#  'сотн': <gensim.models.keyedvectors.Vocab at 0x2a33cad67c0>,
#  'почита': <gensim.models.keyedvectors.Vocab at 0x2a33cad6820>,
#  'въезд': <gensim.models.keyedvectors.Vocab at 0x2a33cad6880>,
#  'статистик': <gensim.models.keyedvectors.Vocab at 0x2a33cad68e0>,
#  'важн': <gensim.models.keyedvectors.Vocab at 0x2a33cad6940>,
#  'вещ': <gensim.models.keyedvectors.Vocab at 0x2a33cad69a0>,
#  'грамотн': <gensim.models.keyedvectors.Vocab at 0x2a33cad6a00>,
#  'пользова': <gensim.models.keyedvectors.Vocab at 0x2a33cad6a60>,
#  'минус': <gensim.models.keyedvectors.Vocab at 0x2a33cad6ac0>,
#  'мужик': <gensim.models.keyedvectors.Vocab at 0x2a33cad6b20>,
#  'народ': <gensim.models.keyedvectors.Vocab at 0x2a33cad6b80>,
#  'личн': <gensim.models.keyedvectors.Vocab at 0x2a33cad6be0>,
#  'непонятн': <gensim.models.keyedvectors.Vocab at 0x2a33cad6c40>,
#  'мнен': <gensim.models.keyedvectors.Vocab at 0x2a33cad6ca0>,
#  'имеет': <gensim.models.keyedvectors.Vocab at 0x2a33cad6d00>,
#  'базис': <gensim.models.keyedvectors.Vocab at 0x2a33cad6d60>,
#  'мужчин': <gensim.models.keyedvectors.Vocab at 0x2a33cad6dc0>,
#  'поеха': <gensim.models.keyedvectors.Vocab at 0x2a33cad6e20>,
#  'срущ': <gensim.models.keyedvectors.Vocab at 0x2a33cad6e80>,
#  'радуг': <gensim.models.keyedvectors.Vocab at 0x2a33cad6ee0>,
#  'быва': <gensim.models.keyedvectors.Vocab at 0x2a33cad6f40>,
#  'скор': <gensim.models.keyedvectors.Vocab at 0x2a33cad6fa0>,
#  'личност': <gensim.models.keyedvectors.Vocab at 0x2a33cad8040>,
#  'появля': <gensim.models.keyedvectors.Vocab at 0x2a33cad80a0>,
#  'предпочита': <gensim.models.keyedvectors.Vocab at 0x2a33cad8100>,
#  'некомфортн': <gensim.models.keyedvectors.Vocab at 0x2a33cad8160>,
#  'чувствова': <gensim.models.keyedvectors.Vocab at 0x2a33cad81c0>,
#  'побольш': <gensim.models.keyedvectors.Vocab at 0x2a33cad8220>,
#  'молча': <gensim.models.keyedvectors.Vocab at 0x2a33cad8280>,
#  'тонкост': <gensim.models.keyedvectors.Vocab at 0x2a33cad82e0>,
#  'долг': <gensim.models.keyedvectors.Vocab at 0x2a33cad8340>,
#  'услуг': <gensim.models.keyedvectors.Vocab at 0x2a33cad83a0>,
#  'жкх': <gensim.models.keyedvectors.Vocab at 0x2a33cad8400>,
#  'квартир': <gensim.models.keyedvectors.Vocab at 0x2a33cad8460>,
#  'отц': <gensim.models.keyedvectors.Vocab at 0x2a33cad84c0>,
#  'вынес': <gensim.models.keyedvectors.Vocab at 0x2a33cad8520>,
#  'ма': <gensim.models.keyedvectors.Vocab at 0x2a33cad8580>,
#  'спуст': <gensim.models.keyedvectors.Vocab at 0x2a33cad85e0>,
#  'врем': <gensim.models.keyedvectors.Vocab at 0x2a33cad8640>,
#  'смерт': <gensim.models.keyedvectors.Vocab at 0x2a33cad86a0>,
#  'наследник': <gensim.models.keyedvectors.Vocab at 0x2a33cad8700>,
#  'закон': <gensim.models.keyedvectors.Vocab at 0x2a33cad8760>,
#  'смс': <gensim.models.keyedvectors.Vocab at 0x2a33cad87c0>,
#  'естествен': <gensim.models.keyedvectors.Vocab at 0x2a33cad8820>,
#  'получ': <gensim.models.keyedvectors.Vocab at 0x2a33cad8880>,
#  'прийт': <gensim.models.keyedvectors.Vocab at 0x2a33cad88e0>,
#  'предъяв': <gensim.models.keyedvectors.Vocab at 0x2a33cad8940>,
#  'наследств': <gensim.models.keyedvectors.Vocab at 0x2a33cad89a0>,
#  'расписа': <gensim.models.keyedvectors.Vocab at 0x2a33cad8a00>,
#  'ознакомл': <gensim.models.keyedvectors.Vocab at 0x2a33cad8a60>,
#  'заявлен': <gensim.models.keyedvectors.Vocab at 0x2a33cad8ac0>,
#  'курс': <gensim.models.keyedvectors.Vocab at 0x2a33cad8b20>,
#  'зомб': <gensim.models.keyedvectors.Vocab at 0x2a33cad8b80>,
#  'главн': <gensim.models.keyedvectors.Vocab at 0x2a33cad8be0>,
#  'налич': <gensim.models.keyedvectors.Vocab at 0x2a33cad8c40>,
#  'исходя': <gensim.models.keyedvectors.Vocab at 0x2a33cad8ca0>,
#  'слюн': <gensim.models.keyedvectors.Vocab at 0x2a33cad8d00>,
#  'безмасочник': <gensim.models.keyedvectors.Vocab at 0x2a33cad8d60>,
#  'дедул': <gensim.models.keyedvectors.Vocab at 0x2a33cad8dc0>,
#  'половин': <gensim.models.keyedvectors.Vocab at 0x2a33cad8e20>,
#  'автобус': <gensim.models.keyedvectors.Vocab at 0x2a33cad8e80>,
#  'постара': <gensim.models.keyedvectors.Vocab at 0x2a33cad8ee0>,
#  'смешн': <gensim.models.keyedvectors.Vocab at 0x2a33cad8f40>,
#  'школ': <gensim.models.keyedvectors.Vocab at 0x2a33cad8fa0>,
#  'ебла': <gensim.models.keyedvectors.Vocab at 0x2a33cada040>,
#  'громч': <gensim.models.keyedvectors.Vocab at 0x2a33cada0a0>,
#  'орут': <gensim.models.keyedvectors.Vocab at 0x2a33cada100>,
#  'ау': <gensim.models.keyedvectors.Vocab at 0x2a33cada160>,
#  'мент': <gensim.models.keyedvectors.Vocab at 0x2a33cada1c0>,
#  'вертел': <gensim.models.keyedvectors.Vocab at 0x2a33cada220>,
#  'мест': <gensim.models.keyedvectors.Vocab at 0x2a33cada280>,
#  'зна': <gensim.models.keyedvectors.Vocab at 0x2a33cada2e0>,
#  'прописыва': <gensim.models.keyedvectors.Vocab at 0x2a33cada340>,
#  'нарушен': <gensim.models.keyedvectors.Vocab at 0x2a33cada3a0>,
#  'инструкц': <gensim.models.keyedvectors.Vocab at 0x2a33cada400>,
#  'рекомендац': <gensim.models.keyedvectors.Vocab at 0x2a33cada460>,
#  'производител': <gensim.models.keyedvectors.Vocab at 0x2a33cada4c0>,
#  'антибиотик': <gensim.models.keyedvectors.Vocab at 0x2a33cada520>,
#  'нагрузк': <gensim.models.keyedvectors.Vocab at 0x2a33cada580>,
#  'организм': <gensim.models.keyedvectors.Vocab at 0x2a33cada5e0>,
#  'мал': <gensim.models.keyedvectors.Vocab at 0x2a33cada640>,
#  'вирусн': <gensim.models.keyedvectors.Vocab at 0x2a33cada6a0>,
#  'бесполезн': <gensim.models.keyedvectors.Vocab at 0x2a33cada700>,
#  'выписыва': <gensim.models.keyedvectors.Vocab at 0x2a33cada760>,
#  'двойн': <gensim.models.keyedvectors.Vocab at 0x2a33cada7c0>,
#  'доз': <gensim.models.keyedvectors.Vocab at 0x2a33cada820>,
#  'назначен': <gensim.models.keyedvectors.Vocab at 0x2a33cada880>,
#  'цефтриаксон': <gensim.models.keyedvectors.Vocab at 0x2a33cada8e0>,
#  'рекомендуем': <gensim.models.keyedvectors.Vocab at 0x2a33cada940>,
#  'пневмон': <gensim.models.keyedvectors.Vocab at 0x2a33cada9a0>,
#  'целесообразн': <gensim.models.keyedvectors.Vocab at 0x2a33cadaa00>,
#  'дальн': <gensim.models.keyedvectors.Vocab at 0x2a33cadaa60>,
#  'прием': <gensim.models.keyedvectors.Vocab at 0x2a33cadaac0>,
#  'должн': <gensim.models.keyedvectors.Vocab at 0x2a33cadab20>,
#  'пересмотрет': <gensim.models.keyedvectors.Vocab at 0x2a33cadab80>,
#  'анализ': <gensim.models.keyedvectors.Vocab at 0x2a33cadabe0>,
#  'фермент': <gensim.models.keyedvectors.Vocab at 0x2a33cadac40>,
#  'печен': <gensim.models.keyedvectors.Vocab at 0x2a33cadaca0>,
#  'азитромицин': <gensim.models.keyedvectors.Vocab at 0x2a33cadad00>,
#  'увеличива': <gensim.models.keyedvectors.Vocab at 0x2a33cadad60>,
#  'дозировк': <gensim.models.keyedvectors.Vocab at 0x2a33cadadc0>,
#  'заочн': <gensim.models.keyedvectors.Vocab at 0x2a33cadae20>,
#  'болезн': <gensim.models.keyedvectors.Vocab at 0x2a33cadae80>,
#  'ясн': <gensim.models.keyedvectors.Vocab at 0x2a33cadaee0>,
#  'последн': <gensim.models.keyedvectors.Vocab at 0x2a33cadaf40>,
#  'конкурент': <gensim.models.keyedvectors.Vocab at 0x2a33cadafa0>,
#  'меньш': <gensim.models.keyedvectors.Vocab at 0x2a33cadc040>,
#  'допуст': <gensim.models.keyedvectors.Vocab at 0x2a33cadc0a0>,
#  'момент': <gensim.models.keyedvectors.Vocab at 0x2a33cadc100>,
#  'прекрат': <gensim.models.keyedvectors.Vocab at 0x2a33cadc160>,
#  'существова': <gensim.models.keyedvectors.Vocab at 0x2a33cadc1c0>,
#  'фарш': <gensim.models.keyedvectors.Vocab at 0x2a33cadc220>,
#  'сперв': <gensim.models.keyedvectors.Vocab at 0x2a33cadc280>,
#  'добав': <gensim.models.keyedvectors.Vocab at 0x2a33cadc2e0>,
#  'дофиг': <gensim.models.keyedvectors.Vocab at 0x2a33cadc340>,
#  'разниц': <gensim.models.keyedvectors.Vocab at 0x2a33cadc3a0>,
#  'мясорубк': <gensim.models.keyedvectors.Vocab at 0x2a33cadc400>,
#  'доверя': <gensim.models.keyedvectors.Vocab at 0x2a33cadc460>,
#  'покупн': <gensim.models.keyedvectors.Vocab at 0x2a33cadc4c0>,
#  'упаковк': <gensim.models.keyedvectors.Vocab at 0x2a33cadc520>,
#  'заводск': <gensim.models.keyedvectors.Vocab at 0x2a33cadc580>,
#  'терпет': <gensim.models.keyedvectors.Vocab at 0x2a33cadc5e0>,
#  'очередн': <gensim.models.keyedvectors.Vocab at 0x2a33cadc640>,
#  'суточн': <gensim.models.keyedvectors.Vocab at 0x2a33cadc6a0>,
#  'собра': <gensim.models.keyedvectors.Vocab at 0x2a33cadc700>,
#  'уеха': <gensim.models.keyedvectors.Vocab at 0x2a33cadc760>,
#  'сочувств': <gensim.models.keyedvectors.Vocab at 0x2a33cadc7c0>,
#  'над': <gensim.models.keyedvectors.Vocab at 0x2a33cadc820>,
#  'украден': <gensim.models.keyedvectors.Vocab at 0x2a33cadc880>,
#  'принесут': <gensim.models.keyedvectors.Vocab at 0x2a33cadc8e0>,
#  'польз': <gensim.models.keyedvectors.Vocab at 0x2a33cadc940>,
#  'спасиб': <gensim.models.keyedvectors.Vocab at 0x2a33cadc9a0>,
#  'инф': <gensim.models.keyedvectors.Vocab at 0x2a33cadca00>,
#  'попробова': <gensim.models.keyedvectors.Vocab at 0x2a33cadca60>,
#  'рацион': <gensim.models.keyedvectors.Vocab at 0x2a33cadcac0>,
#  'выплачива': <gensim.models.keyedvectors.Vocab at 0x2a33cadcb20>,
#  'риелтор': <gensim.models.keyedvectors.Vocab at 0x2a33cadcb80>,
#  'пидор': <gensim.models.keyedvectors.Vocab at 0x2a33cadcbe0>,
#  'слишк': <gensim.models.keyedvectors.Vocab at 0x2a33cadcc40>,
#  'спрос': <gensim.models.keyedvectors.Vocab at 0x2a33cadcca0>,
#  'абсолютн': <gensim.models.keyedvectors.Vocab at 0x2a33cadcd00>,
#  'справедлив': <gensim.models.keyedvectors.Vocab at 0x2a33cadcd60>,
#  'прош': <gensim.models.keyedvectors.Vocab at 0x2a33cadcdc0>,
#  'прощен': <gensim.models.keyedvectors.Vocab at 0x2a33cadce20>,
#  'маленьк': <gensim.models.keyedvectors.Vocab at 0x2a33cadce80>,
#  'опечатк': <gensim.models.keyedvectors.Vocab at 0x2a33cadcee0>,
#  'прот': <gensim.models.keyedvectors.Vocab at 0x2a33cadcf40>,
#  'админ': <gensim.models.keyedvectors.Vocab at 0x2a33cadcfa0>,
#  'исправ': <gensim.models.keyedvectors.Vocab at 0x2a33cade040>,
#  'moderator': <gensim.models.keyedvectors.Vocab at 0x2a33cade0a0>,
#  'исправьт': <gensim.models.keyedvectors.Vocab at 0x2a33cade100>,
#  'пожалуйст': <gensim.models.keyedvectors.Vocab at 0x2a33cade160>,
#  'текст': <gensim.models.keyedvectors.Vocab at 0x2a33cade1c0>,
#  'умничк': <gensim.models.keyedvectors.Vocab at 0x2a33cade220>,
#  'невероятн': <gensim.models.keyedvectors.Vocab at 0x2a33cade280>,
#  'добр': <gensim.models.keyedvectors.Vocab at 0x2a33cade2e0>,
#  'жест': <gensim.models.keyedvectors.Vocab at 0x2a33cade340>,
#  'повод': <gensim.models.keyedvectors.Vocab at 0x2a33cade3a0>,
#  'канал': <gensim.models.keyedvectors.Vocab at 0x2a33cade400>,
#  'неч': <gensim.models.keyedvectors.Vocab at 0x2a33cade460>,
#  'посмотрет': <gensim.models.keyedvectors.Vocab at 0x2a33cade4c0>,
#  'кассет': <gensim.models.keyedvectors.Vocab at 0x2a33cade520>,
#  'пересматрива': <gensim.models.keyedvectors.Vocab at 0x2a33cade580>,
#  'иска': <gensim.models.keyedvectors.Vocab at 0x2a33cade5e0>,
#  'ког': <gensim.models.keyedvectors.Vocab at 0x2a33cade640>,
#  'взят': <gensim.models.keyedvectors.Vocab at 0x2a33cade6a0>,
#  'поменя': <gensim.models.keyedvectors.Vocab at 0x2a33cade700>,
#  'кем': <gensim.models.keyedvectors.Vocab at 0x2a33cade760>,
#  'нит': <gensim.models.keyedvectors.Vocab at 0x2a33cade7c0>,
#  'новеньк': <gensim.models.keyedvectors.Vocab at 0x2a33cade820>,
#  'инет': <gensim.models.keyedvectors.Vocab at 0x2a33cade880>,
#  'зрел': <gensim.models.keyedvectors.Vocab at 0x2a33cade8e0>,
#  'кажд': <gensim.models.keyedvectors.Vocab at 0x2a33cade940>,
#  'шутк': <gensim.models.keyedvectors.Vocab at 0x2a33cade9a0>,
#  'назад': <gensim.models.keyedvectors.Vocab at 0x2a33cadea00>,
#  'повторя': <gensim.models.keyedvectors.Vocab at 0x2a33cadea60>,
#  'пят': <gensim.models.keyedvectors.Vocab at 0x2a33cadeac0>,
#  'дню': <gensim.models.keyedvectors.Vocab at 0x2a33cadeb20>,
#  'ссылк': <gensim.models.keyedvectors.Vocab at 0x2a33cadeb80>,
#  'оригина': <gensim.models.keyedvectors.Vocab at 0x2a33cadebe0>,
#  'лент': <gensim.models.keyedvectors.Vocab at 0x2a33cadec40>,
#  'складыва': <gensim.models.keyedvectors.Vocab at 0x2a33cadeca0>,
#  'кол': <gensim.models.keyedvectors.Vocab at 0x2a33caded00>,
#  'уренго': <gensim.models.keyedvectors.Vocab at 0x2a33caded60>,
#  'умн': <gensim.models.keyedvectors.Vocab at 0x2a33cadedc0>,
#  'пос': <gensim.models.keyedvectors.Vocab at 0x2a33cadee20>,
#  'симпат': <gensim.models.keyedvectors.Vocab at 0x2a33cadee80>,
#  'маскир': <gensim.models.keyedvectors.Vocab at 0x2a33cadeee0>,
#  'тщательн': <gensim.models.keyedvectors.Vocab at 0x2a33cadef40>,
#  'фотк': <gensim.models.keyedvectors.Vocab at 0x2a33cadefa0>,
#  'увидел': <gensim.models.keyedvectors.Vocab at 0x2a33cae0040>,
#  'стро': <gensim.models.keyedvectors.Vocab at 0x2a33cae00a0>,
#  'гараж': <gensim.models.keyedvectors.Vocab at 0x2a33cae0100>,
#  'пизд': <gensim.models.keyedvectors.Vocab at 0x2a33cae0160>,
#  'поколен': <gensim.models.keyedvectors.Vocab at 0x2a33cae01c0>,
#  'вспомина': <gensim.models.keyedvectors.Vocab at 0x2a33cae0220>,
#  'средн': <gensim.models.keyedvectors.Vocab at 0x2a33cae0280>,
#  'нечт': <gensim.models.keyedvectors.Vocab at 0x2a33cae02e0>,
#  'зелен': <gensim.models.keyedvectors.Vocab at 0x2a33cae0340>,
#  'черн': <gensim.models.keyedvectors.Vocab at 0x2a33cae03a0>,
#  'компьютер': <gensim.models.keyedvectors.Vocab at 0x2a33cae0400>,
#  'сигнал': <gensim.models.keyedvectors.Vocab at 0x2a33cae0460>,
#  'датчик': <gensim.models.keyedvectors.Vocab at 0x2a33cae04c0>,
#  'генерир': <gensim.models.keyedvectors.Vocab at 0x2a33cae0520>,
#  'экран': <gensim.models.keyedvectors.Vocab at 0x2a33cae0580>,
#  'сильн': <gensim.models.keyedvectors.Vocab at 0x2a33cae05e0>,
#  'прозрачн': <gensim.models.keyedvectors.Vocab at 0x2a33cae0640>,
#  'зеркал': <gensim.models.keyedvectors.Vocab at 0x2a33cae06a0>,
#  'пилот': <gensim.models.keyedvectors.Vocab at 0x2a33cae0700>,
#  'отража': <gensim.models.keyedvectors.Vocab at 0x2a33cae0760>,
#  'глаз': <gensim.models.keyedvectors.Vocab at 0x2a33cae07c0>,
#  'сидя': <gensim.models.keyedvectors.Vocab at 0x2a33cae0820>,
#  'пикаб': <gensim.models.keyedvectors.Vocab at 0x2a33cae0880>,
#  'холоп': <gensim.models.keyedvectors.Vocab at 0x2a33cae08e0>,
#  'умор': <gensim.models.keyedvectors.Vocab at 0x2a33cae0940>,
#  'миллиардер': <gensim.models.keyedvectors.Vocab at 0x2a33cae09a0>,
#  'видим': <gensim.models.keyedvectors.Vocab at 0x2a33cae0a00>,
#  'глубин': <gensim.models.keyedvectors.Vocab at 0x2a33cae0a60>,
#  'правительств': <gensim.models.keyedvectors.Vocab at 0x2a33cae0ac0>,
#  'дзюб': <gensim.models.keyedvectors.Vocab at 0x2a33cae0b20>,
#  'наброс': <gensim.models.keyedvectors.Vocab at 0x2a33cae0b80>,
#  'подроч': <gensim.models.keyedvectors.Vocab at 0x2a33cae0be0>,
#  'секс': <gensim.models.keyedvectors.Vocab at 0x2a33cae0c40>,
#  'чат': <gensim.models.keyedvectors.Vocab at 0x2a33cae0ca0>,
#  'дроч': <gensim.models.keyedvectors.Vocab at 0x2a33cae0d00>,
#  'назов': <gensim.models.keyedvectors.Vocab at 0x2a33cae0d60>,
#  'жду': <gensim.models.keyedvectors.Vocab at 0x2a33cae0dc0>,
#  'прицел': <gensim.models.keyedvectors.Vocab at 0x2a33cae0e20>,
#  'лазерн': <gensim.models.keyedvectors.Vocab at 0x2a33cae0e80>,
#  'луч': <gensim.models.keyedvectors.Vocab at 0x2a33cae0ee0>,
#  'бьет': <gensim.models.keyedvectors.Vocab at 0x2a33cae0f40>,
#  'поспор': <gensim.models.keyedvectors.Vocab at 0x2a33cae0fa0>,
#  'жил': <gensim.models.keyedvectors.Vocab at 0x2a33cae2040>,
#  'говн': <gensim.models.keyedvectors.Vocab at 0x2a33cae20a0>,
#  'прож': <gensim.models.keyedvectors.Vocab at 0x2a33cae2100>,
#  'деревн': <gensim.models.keyedvectors.Vocab at 0x2a33cae2160>,
#  'вылаз': <gensim.models.keyedvectors.Vocab at 0x2a33cae21c0>,
#  'копан': <gensim.models.keyedvectors.Vocab at 0x2a33cae2220>,
#  'принос': <gensim.models.keyedvectors.Vocab at 0x2a33cae2280>,
#  'доход': <gensim.models.keyedvectors.Vocab at 0x2a33cae22e0>,
#  'эконом': <gensim.models.keyedvectors.Vocab at 0x2a33cae2340>,
#  'коп': <gensim.models.keyedvectors.Vocab at 0x2a33cae23a0>,
#  'телевизор': <gensim.models.keyedvectors.Vocab at 0x2a33cae2400>,
#  'либ': <gensim.models.keyedvectors.Vocab at 0x2a33cae2460>,
#  'вкус': <gensim.models.keyedvectors.Vocab at 0x2a33cae24c0>,
#  'интерьер': <gensim.models.keyedvectors.Vocab at 0x2a33cae2520>,
#  'имел': <gensim.models.keyedvectors.Vocab at 0x2a33cae2580>,
#  'телек': <gensim.models.keyedvectors.Vocab at 0x2a33cae25e0>,
#  'показыва': <gensim.models.keyedvectors.Vocab at 0x2a33cae2640>,
#  'изыск': <gensim.models.keyedvectors.Vocab at 0x2a33cae26a0>,
#  'богат': <gensim.models.keyedvectors.Vocab at 0x2a33cae2700>,
#  'тип': <gensim.models.keyedvectors.Vocab at 0x2a33cae2760>,
#  'золот': <gensim.models.keyedvectors.Vocab at 0x2a33cae27c0>,
#  'унитаз': <gensim.models.keyedvectors.Vocab at 0x2a33cae2820>,
#  'трех': <gensim.models.keyedvectors.Vocab at 0x2a33cae2880>,
#  'потолк': <gensim.models.keyedvectors.Vocab at 0x2a33cae28e0>,
#  'машин': <gensim.models.keyedvectors.Vocab at 0x2a33cae2940>,
#  'цвет': <gensim.models.keyedvectors.Vocab at 0x2a33cae29a0>,
#  'шо': <gensim.models.keyedvectors.Vocab at 0x2a33cae2a00>,
#  'уб': <gensim.models.keyedvectors.Vocab at 0x2a33cae2a60>,
#  'откуд': <gensim.models.keyedvectors.Vocab at 0x2a33cae2ac0>,
#  'взял': <gensim.models.keyedvectors.Vocab at 0x2a33cae2b20>,
#  'представлен': <gensim.models.keyedvectors.Vocab at 0x2a33cae2b80>,
#  'перееха': <gensim.models.keyedvectors.Vocab at 0x2a33cae2be0>,
#  'устро': <gensim.models.keyedvectors.Vocab at 0x2a33cae2c40>,
#  'начальник': <gensim.models.keyedvectors.Vocab at 0x2a33cae2ca0>,
#  'паца': <gensim.models.keyedvectors.Vocab at 0x2a33cae2d00>,
#  'деревенск': <gensim.models.keyedvectors.Vocab at 0x2a33cae2d60>,
#  'скажеш': <gensim.models.keyedvectors.Vocab at 0x2a33cae2dc0>,
#  'знающ': <gensim.models.keyedvectors.Vocab at 0x2a33cae2e20>,
#  'мер': <gensim.models.keyedvectors.Vocab at 0x2a33cae2e80>,
#  'общен': <gensim.models.keyedvectors.Vocab at 0x2a33cae2ee0>,
#  'применен': <gensim.models.keyedvectors.Vocab at 0x2a33cae2f40>,
#  'имеющ': <gensim.models.keyedvectors.Vocab at 0x2a33cae2fa0>,
#  'родител': <gensim.models.keyedvectors.Vocab at 0x2a33cae4040>,
#  'воспита': <gensim.models.keyedvectors.Vocab at 0x2a33cae40a0>,
#  'быдл': <gensim.models.keyedvectors.Vocab at 0x2a33cae4100>,
#  'колхозн': <gensim.models.keyedvectors.Vocab at 0x2a33cae4160>,
#  'замашк': <gensim.models.keyedvectors.Vocab at 0x2a33cae41c0>,
#  'чем': <gensim.models.keyedvectors.Vocab at 0x2a33cae4220>,
#  'обща': <gensim.models.keyedvectors.Vocab at 0x2a33cae4280>,
#  'хоч': <gensim.models.keyedvectors.Vocab at 0x2a33cae42e0>,
#  'выглядет': <gensim.models.keyedvectors.Vocab at 0x2a33cae4340>,
#  'большинств': <gensim.models.keyedvectors.Vocab at 0x2a33cae43a0>,
#  'колхоз': <gensim.models.keyedvectors.Vocab at 0x2a33cae4400>,
#  'похер': <gensim.models.keyedvectors.Vocab at 0x2a33cae4460>,
#  ...}

# %%
# чтобы получить вектор конкретного слова, можно использовать функцию get_vector

model.wv.get_vector('кошк')
# Out:
# array([-0.3226964 ,  0.6393302 ,  0.45441407,  0.2224026 ,  0.06319614,
#        -0.07098959,  0.49146298, -0.46238947,  0.4805155 ,  0.09468808,
#        -0.12805012, -0.4840694 ,  0.22814453, -0.4035352 , -0.01974358,
#        -0.36535627, -0.72279793, -0.08781783, -0.47936466,  0.11207724,
#        -0.11807988,  0.26683843, -0.0120027 ,  0.52062637,  0.06033983,
#         0.27940103,  0.3757668 , -0.4560905 , -0.6632277 ,  0.00259031,
#        -0.01712201,  0.28063554, -0.7654456 , -0.6377426 ,  0.6656281 ,
#         0.26438177, -0.16118546, -0.4786781 , -0.31584165, -0.2583714 ,
#        -0.3717855 ,  0.08922195, -0.2445172 , -0.5488379 ,  0.6663653 ,
#         0.06839547, -0.49663448,  0.1346117 ,  0.07618333,  0.26467648,
#         0.16262884,  0.6348045 ,  0.17031457, -0.13500424,  0.22544916,
#        -0.52601004, -0.51442814,  0.14677349,  0.08039584,  0.00743247,
#         0.01623051,  0.22153434,  0.07267933,  0.01137718,  0.1206939 ,
#         0.18941152,  0.09962156,  0.10290947, -0.18843654,  0.23921035,
#         0.06712376,  0.44440588,  0.00578922, -0.11963339, -0.05805062,
#         0.1361616 , -0.17528667,  0.08252984, -0.00163212, -0.22121051,
#         0.00713235,  0.24077153, -0.3056224 , -0.33465838,  0.14596194,
#        -0.04109763,  0.23788716,  0.04038512, -0.11222932,  0.18838736,
#        -0.06599316, -0.56060284,  0.24168485, -0.14545283, -0.16593286,
#         0.2635063 ,  0.17842542,  0.1108654 , -0.0466946 , -0.02500557],
#       dtype=float32)

# %% [markdown]
# Самым важным свойством word2vec-моделей является тот факт, что они распознают контекст: близкие по смыслу слова будут находиться где-то рядом в векторном пространстве.
#
# Например, давайте посмотрим на самые близкие слова к словам "король", "автомобиль" и "компьютер".

# %%
model.wv.most_similar(positive=stemmer.stem('король'), topn=5)
# Out:
# [('ферз', 0.584980845451355),
#  ('рыцар', 0.5687369108200073),
#  ('герцог', 0.5446561574935913),
#  ('лучник', 0.5414139032363892),
#  ('xiii', 0.5260868668556213)]

# %%
model.wv.most_similar(positive=stemmer.stem('автомобиль'), topn=5)
# Out:
# [('авт', 0.7663224935531616),
#  ('машин', 0.7254810929298401),
#  ('велосипед', 0.664608359336853),
#  ('колес', 0.6353932619094849),
#  ('легков', 0.6232739090919495)]

# %%
model.wv.most_similar(positive=stemmer.stem('компьютер'), topn=5)
# Out:
# [('комп', 0.7024422883987427),
#  ('смартфон', 0.6496104001998901),
#  ('телефон', 0.5985431671142578),
#  ('планшет', 0.5940207839012146),
#  ('залогин', 0.5915631055831909)]

# %% [markdown]
# Со словами теперь можно производить векторные операции. Давайте посмотрим, что получится, если, например, из слова "собака" вычесть компонент "плохой" и добавить "хороший":

# %%
# в аргументе negative указываем слово, которое будем вычитать

model.wv.most_similar(positive=[stemmer.stem('собака'), stemmer.stem('хороший')], negative=[stemmer.stem('плохой')], topn=1)
# Out:
# [('кошк', 0.6429858207702637)]

# %%
# ещё пример: кто такие "больше дети"?

model.wv.most_similar(positive=[stemmer.stem('дети'), stemmer.stem('большой')], negative=[stemmer.stem('маленький')], topn=1)
# Out:
# [('родител', 0.5666666626930237)]

# %% [markdown]
# Можно также определять, какое слово в ряду "лишнее": т.е. какое слово меньше всего "похоже" на остальные в среднем.

# %%
# овощи против яблока

model.wv.doesnt_match([stemmer.stem('капуста'), 
                       stemmer.stem('помидор'), 
                       stemmer.stem('кабачок'),
                       stemmer.stem('яблоко')])
# Out:
# c:\users\g0nzalez\venv38\lib\site-packages\gensim\models\keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'яблок'

# %%
# танцор против "суровых профессий"

model.wv.doesnt_match([stemmer.stem('сварщик'), 
                       stemmer.stem('строитель'), 
                       stemmer.stem('танцор'), 
                       stemmer.stem('каменщик'), 
                       stemmer.stem('плиточник')])
# Out:
# 'танцор'

# %% [markdown]
# Можем посмотреть, какое слово ближе всего подходит к указанному.

# %%
# какое из слов лучше всего характеризует волка?

model.wv.most_similar_to_given(stemmer.stem('волк'), [stemmer.stem('добрый'), 
                                                      stemmer.stem('хитрый'), 
                                                      stemmer.stem('злой'), 
                                                      stemmer.stem('красивый'), 
                                                      stemmer.stem('шерстяной')])
# Out:
# 'зло'

# %% [markdown]
# Сама по себе word2vec-модель не решает какую-то практическую задачу, но она служит отличным ембедингом, который затем мы сможем использовать в других задачах, связанных с текстом.
